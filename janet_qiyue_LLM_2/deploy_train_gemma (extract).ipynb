# %%
from sagemaker.jumpstart.estimator import JumpStartEstimator

training_job_name = "jumpstart-dft-huggingface-llm-gemma-20240728-235710"
model_id = "huggingface-llm-gemma-7b-instruct"

attached_estimator = JumpStartEstimator.attach(training_job_name, model_id)
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# Using model 'huggingface-llm-gemma-7b-instruct' with wildcard version identifier '*'. You can pin to version '1.2.0' for more stable results. Note that models may have different input/output signatures after a major version upgrade.
# 2024-07-29 01:07:36 Starting - Preparing the instances for training
# 2024-07-29 01:07:36 Downloading - Downloading the training image
# 2024-07-29 01:07:36 Training - Training image download completed. Training in progress.
# 2024-07-29 01:07:36 Uploading - Uploading generated training model
# 2024-07-29 01:07:36 Completed - Training job completed

# %%
instance_type = "ml.g5.12xlarge"

fine_tuned_model = attached_estimator.deploy(instance_type=instance_type)
# Out:
# ----------!

# %%
import sacrebleu
from rouge import Rouge
import pandas as pd
import re
import json

def extract_referral_content(text):
    # 使用正则表达式匹配倒数第二个和最后一个双引号之间的内容
    pattern = r'"([^"]*)"\s*[^"]*$'
    match = re.search(pattern, text)
    # print(f"Extracting referral_content from text:\n{text}")  # 调试信息
    if match:
        return match.group(1)
    else:
        return "extract failure"
    
    
def extract_is_papilledema(prediction_text):
    try:
        # 使用正则表达式从生成的文本中提取最后一个 is_Papilledema 的值，不管中间有什么符号
        is_papilledema_matches = list(re.finditer(r'is_Papilledema.*?(True|False)', prediction_text, re.IGNORECASE))
        if is_papilledema_matches:
            last_match = is_papilledema_matches[-1]
            return "True" if last_match.group(1).lower() == 'true' else "False"
        else:
            return "extract failure"
    except Exception as err:
        return "extract failure"



    
def evaluate_testjsonl_with_gemma(reference_path, csv_file_path):
    
    test_data_json = []
    
    with open(reference_path, 'r', encoding='utf-8') as f:
        for line in f:
              test_data_json.append(json.loads(line.strip()))
    
    rouge_score_list = []
    bleu_score_list = []
              
    rouge = Rouge()
              
    prediction_list = []
              
    for single_test in test_data_json:
        instruction = single_test["instruction"]
        whole_letter = single_test["whole_letter"]
        referral_content = single_test["referral_content"]
        prompt = f"{instruction}\n\n###\n\n{whole_letter}\n\n###"
        response = fine_tuned_model.predict({'inputs': prompt, 'parameters': {'max_new_tokens': 256}})
        # response = origin_model.predict({prompt})

        reference_text = referral_content
        # print(response[0])
        try:
            # print("response: " + response)
            # response = reponse[0] if isinstance(response, list) else response
            # print("response: " + response)
            # prediction_dict = json.loads(response["generated_text"].strip())
            prediction_text = response[0]["generated_text"].strip()
            # print(prediction_text)
            
            extracted_referral_content = extract_referral_content(prediction_text)
            # print(extracted_referral_content)
            
            extracted_is_papilledema = extract_is_papilledema(prediction_text)
            # print(extracted_is_papilledema)
            
            
            single_test["predict_referral_content"] = extracted_referral_content
            single_test["predict_is_papilledema"] = extracted_is_papilledema
           
          
        except Exception as err:
            prediction_text = "extract failure"
        finally:
            # prediction_list.append(extracted_referral_content)
            print("is_papilledema_prediction: " + extracted_is_papilledema + "\n")
            print("referral_content_prediction: " + extracted_referral_content + "\n")
            print("ground_truth: " + reference_text)
            print("=============================")

        bleu_score = sacrebleu.corpus_bleu([extracted_referral_content], [[reference_text]])
        bleu_score_list.append(bleu_score.score)
        single_test["bleu"] = bleu_score.score

        rouge_score = rouge.get_scores(extracted_referral_content, reference_text)
        rouge_score_list.append(rouge_score)
        
        
        
    # 创建 CSV 文件
    csv_data = []

    for single_test in test_data_json:
        csv_data.append({
            # "id": single_test["id"],
            # "name": single_test["name"],
            "instruction": single_test["instruction"],
            "whole_letter": single_test["whole_letter"],
            "referral_content": single_test["referral_content"],
            "predict_referral_content": single_test["predict_referral_content"],
            "bleu": single_test["bleu"],
            "is_papilledema": single_test["predict_is_papilledema"],
        })

    # 创建 DataFrame
    df = pd.DataFrame(csv_data)

    # 保存为 CSV 文件
    df.to_csv(csv_file_path, index=False, encoding='utf-8')

    print(f"CSV file has been saved to {csv_file_path}")
        
    return bleu_score_list

# %%
bleu_score_list = evaluate_testjsonl_with_gemma("../test.jsonl", "./gemma_trainModel_result.csv")
# Out:
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
#
# ground_truth: The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement.
#
# ground_truth: Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement. Imaging studies including cervical spine radiograph, which showed apparent kyphosis, and MRI, which indicated no spinal cord compression, have been performed.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
#
# ground_truth: We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
#
# ground_truth: The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
#
# ground_truth: Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
#
# ground_truth: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
#
# ground_truth: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
#
# ground_truth: The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
#
# ground_truth: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
#
# ground_truth: Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
#
# ground_truth: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended.
#
# ground_truth: The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
#
# ground_truth: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
#
# ground_truth: The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mrs. Thompson has been experiencing frequent episodes of chest pain and shortness of breath over the past three months. Despite initial management with beta-blockers, there has been minimal improvement. Her recent EKG showed nonspecific ST-segment changes, raising concerns for underlying ischemic heart disease.
#
# ground_truth: Mrs. Thompson has been experiencing frequent episodes of chest pain and shortness of breath over the past three months. Despite initial management with beta-blockers, there has been minimal improvement. Her recent EKG showed nonspecific ST-segment changes, raising concerns for underlying ischemic heart disease.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Despite the successful placement of the gingiva-colored restorations, the patient continues to experience persistent sensitivity in the left maxillary region, suggesting the potential for an underlying issue that requires further evaluation and management by a specialist.
#
# ground_truth: Despite the successful placement of the gingiva-colored restorations, the patient continues to experience persistent sensitivity in the left maxillary region, suggesting the potential for an underlying issue that requires further evaluation and management by a specialist.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to seek your specialized assistance in the management of her persistent skin problems attributed to excess overhanging skin. While an infraumbilical panniculectomy with umbilical transposition had been previously performed, her skin issues necessitate further evaluation and potential intervention.
#
# ground_truth: The reason for this referral is to seek your specialized assistance in the management of her persistent skin problems attributed to excess overhanging skin. While an infraumbilical panniculectomy with umbilical transposition had been previously performed, her skin issues necessitate further evaluation and potential intervention.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to seek your expertise in developing a long-term oncological surveillance and management plan for Mr. Doe, given his high-grade urothelial carcinoma and previous surgical interventions.
#
# ground_truth: The reason for this referral is to seek your expertise in developing a long-term oncological surveillance and management plan for Mr. Doe, given his high-grade urothelial carcinoma and previous surgical interventions.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the persistence of her symptoms despite treatment, I am concerned that there may be an underlying condition that requires further specialized investigation.
#
# ground_truth: Given the persistence of her symptoms despite treatment, I am concerned that there may be an underlying condition that requires further specialized investigation.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the complexity of Mrs. Smith's ocular conditions and her recent improvement, she requires specialized follow-up to optimize her visual outcome and monitor for potential recurrence or complications.
#
# ground_truth: Given the complexity of Mrs. Smith's ocular conditions and her recent improvement, she requires specialized follow-up to optimize her visual outcome and monitor for potential recurrence or complications.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is for further evaluation and management of her diabetes, as she has shown an initial response to sitagliptin but has had a slight weight gain of 1kg. Her fructosamine levels have decreased significantly, showing a reduction equivalent to a 0.3% and 1.2% decrease in HbA1c at 6 and 12 months, respectively. However, additional expertise in diabetes management may be beneficial for optimizing her treatment and preventing further complications.
#
# ground_truth: The referral is for further evaluation and management of her diabetes, as she has shown an initial response to sitagliptin but has had a slight weight gain of 1kg. Her fructosamine levels have decreased significantly, showing a reduction equivalent to a 0.3% and 1.2% decrease in HbA1c at 6 and 12 months, respectively. However, additional expertise in diabetes management may be beneficial for optimizing her treatment and preventing further complications.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is necessary to ensure the continued monitoring and management of her facial scarring, to evaluate the long-term effectiveness of the fat injections, and to discuss potential adjunctive treatments if required.
#
# ground_truth: The referral is necessary to ensure the continued monitoring and management of her facial scarring, to evaluate the long-term effectiveness of the fat injections, and to discuss potential adjunctive treatments if required.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe requires a specialist evaluation for the confirmed diagnosis and management of his onychomycosis. Given its persistence and unresponsiveness to initial therapies, a specialist's insights are imperative for targeted treatment.
#
# ground_truth: Mr. Doe requires a specialist evaluation for the confirmed diagnosis and management of his onychomycosis. Given its persistence and unresponsiveness to initial therapies, a specialist's insights are imperative for targeted treatment.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Referral is being sought for further evaluation and management due to the initial severity of the condition and to ensure ongoing stability given her medical history.
#
# ground_truth: Referral is being sought for further evaluation and management due to the initial severity of the condition and to ensure ongoing stability given her medical history.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral reason is the need for specialized post-operative care following a recent VATS lobectomy. Despite a relatively stable post-operative course, Mr. Doe's complex medical history necessitates continued expert assessment to optimize his recovery and manage any potential complications.
#
# ground_truth: The referral reason is the need for specialized post-operative care following a recent VATS lobectomy. Despite a relatively stable post-operative course, Mr. Doe's complex medical history necessitates continued expert assessment to optimize his recovery and manage any potential complications.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Further evaluation from a specialist is necessary to confirm the diagnosis and to establish an appropriate management plan for Mr. Doe's oral ulcers.
#
# ground_truth: Further evaluation from a specialist is necessary to confirm the diagnosis and to establish an appropriate management plan for Mr. Doe's oral ulcers.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is necessitated by Ms. Doe’s significant reaction to the blue dye, including a recorded 6 mm positive reaction on skin prick test (SPT) with patent blue V, while having no previous history of allergy or atopy. Her peak MCT levels rose to 12.1 ng/mL post-reaction, markedly higher than her baseline of 3.2 ng/mL. This suggests the possibility of a specific allergy that needs further investigation and management.
#
# ground_truth: The referral is necessitated by Ms. Doe’s significant reaction to the blue dye, including a recorded 6 mm positive reaction on skin prick test (SPT) with patent blue V, while having no previous history of allergy or atopy. Her peak MCT levels rose to 12.1 ng/mL post-reaction, markedly higher than her baseline of 3.2 ng/mL. This suggests the possibility of a specific allergy that needs further investigation and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is specifically for a detailed otologic and neurologic evaluation. Intense postFLAIR-enhancement was observed in the cochlea, vestibule, and semicircular canal, along with significant enhancement involving the cochlear nerve. This suggests potential complications that require specialist input.
#
# ground_truth: The referral is specifically for a detailed otologic and neurologic evaluation. Intense postFLAIR-enhancement was observed in the cochlea, vestibule, and semicircular canal, along with significant enhancement involving the cochlear nerve. This suggests potential complications that require specialist input.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for the referral is to ensure specialized perioperative care, considering her multiple drug allergies and her requirement for a total thyroidectomy. She needs thorough preoperative evaluation and management from a multidisciplinary team aimed at minimizing the risk of allergic reactions.
#
# ground_truth: The reason for the referral is to ensure specialized perioperative care, considering her multiple drug allergies and her requirement for a total thyroidectomy. She needs thorough preoperative evaluation and management from a multidisciplinary team aimed at minimizing the risk of allergic reactions.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to ensure Mr. Doe receives comprehensive post-discharge care, focusing on the management and follow-up of his multiple chronic conditions, especially given his recent COVID-19 infection.
#
# ground_truth: The reason for this referral is to ensure Mr. Doe receives comprehensive post-discharge care, focusing on the management and follow-up of his multiple chronic conditions, especially given his recent COVID-19 infection.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: We are referring Ms. Doe to your esteemed clinic for further evaluation and management of her large hiatal hernia and potential complications from the extrinsic mass compressing the left atrium. Due to the complexity of her condition, specialized assessment and treatment are necessary to ensure her well-being.
#
# ground_truth: We are referring Ms. Doe to your esteemed clinic for further evaluation and management of her large hiatal hernia and potential complications from the extrinsic mass compressing the left atrium. Due to the complexity of her condition, specialized assessment and treatment are necessary to ensure her well-being.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to obtain specialized orthopedic evaluation and further management for Ms. Doe’s left tibial plateau fracture and associated injuries.
#
# ground_truth: The reason for this referral is to obtain specialized orthopedic evaluation and further management for Ms. Doe’s left tibial plateau fracture and associated injuries.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Smith requires specialized orthopedic evaluation to confirm the diagnosis of osteonecrosis of the lunate and to develop an appropriate treatment plan, including the potential need for surgical intervention.
#
# ground_truth: Mr. Smith requires specialized orthopedic evaluation to confirm the diagnosis of osteonecrosis of the lunate and to develop an appropriate treatment plan, including the potential need for surgical intervention.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the acute onset of altered sensorium and persistent fever, a more comprehensive neurological evaluation is warranted to rule out potential central nervous system infections or other neurological conditions. Your expertise is essential in further diagnostic workup and management.
#
# ground_truth: Given the acute onset of altered sensorium and persistent fever, a more comprehensive neurological evaluation is warranted to rule out potential central nervous system infections or other neurological conditions. Your expertise is essential in further diagnostic workup and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the complexity and range of his symptoms, I believe a specialist’s evaluation is warranted to determine the underlying cause and appropriate treatment plan.
#
# ground_truth: Given the complexity and range of his symptoms, I believe a specialist’s evaluation is warranted to determine the underlying cause and appropriate treatment plan.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is sought to investigate and manage the ongoing complications resulting from the infection and subsequent surgeries, specifically the air leak and confirmed AEF.
#
# ground_truth: The referral is sought to investigate and manage the ongoing complications resulting from the infection and subsequent surgeries, specifically the air leak and confirmed AEF.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is her complex symptomatology and the need for further specialized evaluation to determine any underlying genetic conditions that might explain her physical anomalies and epilepsy.
#
# ground_truth: The reason for this referral is her complex symptomatology and the need for further specialized evaluation to determine any underlying genetic conditions that might explain her physical anomalies and epilepsy.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for referral is to seek advanced evaluation and management options given the patient's high Gleason score and significant PSA levels.
#
# ground_truth: The reason for referral is to seek advanced evaluation and management options given the patient's high Gleason score and significant PSA levels.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral reason is the noted proptosis of uncertain duration and significant imaging findings suggestive of an underlying inflammatory or infiltrative process. Further specialist input is required to determine the precise diagnosis and appropriate care plan.
#
# ground_truth: The referral reason is the noted proptosis of uncertain duration and significant imaging findings suggestive of an underlying inflammatory or infiltrative process. Further specialist input is required to determine the precise diagnosis and appropriate care plan.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Smith requires further oncologic evaluation and management of transitional cell carcinoma. Your expert assessment and recommendations for the most appropriate therapeutic options will be greatly appreciated.
#
# ground_truth: Mr. Smith requires further oncologic evaluation and management of transitional cell carcinoma. Your expert assessment and recommendations for the most appropriate therapeutic options will be greatly appreciated.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Smith requires further evaluation and specialized management to ascertain the nature of this mass and appropriate treatment.
#
# ground_truth: Mr. Smith requires further evaluation and specialized management to ascertain the nature of this mass and appropriate treatment.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to ensure ongoing specialized care and follow-up management. Mr. Doe's complex medical history and recent surgical intervention warrant continued surveillance by a specialist in this field.
#
# ground_truth: The reason for this referral is to ensure ongoing specialized care and follow-up management. Mr. Doe's complex medical history and recent surgical intervention warrant continued surveillance by a specialist in this field.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Ms. Doe requires further evaluation and possible intervention for the cystic tumor in her mediastinum. Given its size and location, your expertise in thoracic oncology would be greatly valuable in determining the appropriate course of action.
#
# ground_truth: Ms. Doe requires further evaluation and possible intervention for the cystic tumor in her mediastinum. Given its size and location, your expertise in thoracic oncology would be greatly valuable in determining the appropriate course of action.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for referral is for specialized management of Mr. Smith’s postoperative progress and any further necessary interventions to optimize recovery. Your expertise will be invaluable in ensuring his continued improvement and addressing any potential complications.
#
# ground_truth: The primary reason for referral is for specialized management of Mr. Smith’s postoperative progress and any further necessary interventions to optimize recovery. Your expertise will be invaluable in ensuring his continued improvement and addressing any potential complications.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe requires further specialized assessment and management of his deteriorating liver function and ongoing vision and hearing impairment. Immediate evaluation by a hepatic specialist and a neurologist is highly recommended to address these issues comprehensively.
#
# ground_truth: Mr. Doe requires further specialized assessment and management of his deteriorating liver function and ongoing vision and hearing impairment. Immediate evaluation by a hepatic specialist and a neurologist is highly recommended to address these issues comprehensively.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mrs. Johnson has been struggling with Generalized Granuloma Annulare (GGA) for the past five years. Despite various topical treatments, including pimecrolimus 0.1% cream, triamcinolone 0.5% cream, desoximetasone 0.25% cream, and flurandrenolide tape, she has only experienced mild improvements. A three-month course of pentoxifylline and oral vitamin E provided some benefits, particularly noticeable in her distal upper extremities. I am referring her to you for further evaluation and potential advanced therapies.
#
# ground_truth: Mrs. Johnson has been struggling with Generalized Granuloma Annulare (GGA) for the past five years. Despite various topical treatments, including pimecrolimus 0.1% cream, triamcinolone 0.5% cream, desoximetasone 0.25% cream, and flurandrenolide tape, she has only experienced mild improvements. A three-month course of pentoxifylline and oral vitamin E provided some benefits, particularly noticeable in her distal upper extremities. I am referring her to you for further evaluation and potential advanced therapies.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the findings of hepatitis and membrano-proliferative glomerulonephritis, I believe further specialist evaluation is required to manage his condition effectively.
#
# ground_truth: Given the findings of hepatitis and membrano-proliferative glomerulonephritis, I believe further specialist evaluation is required to manage his condition effectively.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The purpose of this referral is for specialized cardiological evaluation and management. Given the complex nature of her cardiac anomalies and symptoms, she would benefit immensely from your expertise.
#
# ground_truth: The purpose of this referral is for specialized cardiological evaluation and management. Given the complex nature of her cardiac anomalies and symptoms, she would benefit immensely from your expertise.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to ensure comprehensive follow-up and monitoring for any potential complications related to the Anisakis simplex infection, as well as to prevent recurrence and manage any residual gastrointestinal symptoms. A specialist's opinion and further endoscopic evaluation may be warranted.
#
# ground_truth: The reason for this referral is to ensure comprehensive follow-up and monitoring for any potential complications related to the Anisakis simplex infection, as well as to prevent recurrence and manage any residual gastrointestinal symptoms. A specialist's opinion and further endoscopic evaluation may be warranted.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is necessary due to the unusual arrangement of the piriformis muscle and the early splitting of the left sciatic nerve, where the common peroneal component passes through the two heads of the piriformis muscle. This configuration may have clinical implications that warrant further investigation by a specialist.
#
# ground_truth: The referral is necessary due to the unusual arrangement of the piriformis muscle and the early splitting of the left sciatic nerve, where the common peroneal component passes through the two heads of the piriformis muscle. This configuration may have clinical implications that warrant further investigation by a specialist.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for this referral is the patient's chronic and poorly controlled hypertension, which has not responded adequately to multiple antihypertensive medications. Despite adherence to a comprehensive treatment plan encompassing lifestyle modifications and pharmacological therapy, Mr. Doe continues to experience elevated blood pressure readings, averaging 160/100 mmHg over the past three months. This is concerning given his increased risk for cardiovascular events and organ damage.
#
# ground_truth: The primary reason for this referral is the patient's chronic and poorly controlled hypertension, which has not responded adequately to multiple antihypertensive medications. Despite adherence to a comprehensive treatment plan encompassing lifestyle modifications and pharmacological therapy, Mr. Doe continues to experience elevated blood pressure readings, averaging 160/100 mmHg over the past three months. This is concerning given his increased risk for cardiovascular events and organ damage.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral reason is the confirmed diagnosis of isolated cardiac apical cystic echinococcosis in the left ventricular apex detected via echocardiography and confirmed by computed tomography. Despite being recommended for surgery, the patient has refused the operation.
#
# ground_truth: The referral reason is the confirmed diagnosis of isolated cardiac apical cystic echinococcosis in the left ventricular apex detected via echocardiography and confirmed by computed tomography. Despite being recommended for surgery, the patient has refused the operation.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is due to findings from an upper endoscopic biopsy which confirmed gastric cancer. Further staging with FDG-PET/CT has demonstrated not only increased FDG accumulation at the primary tumor site but also multiple metastatic intra-abdominal lymphadenopathies and a left supraclavicular lymph node. Additionally, there is widespread heterogeneous FDG uptake in the axial skeleton indicative of bone marrow involvement. The patient's hemoglobin was recorded at 9.5 g/dL, WBC at 4,100, and PLT at 33,000 per µL. A bone marrow biopsy has shown metastatic gastric cancer.
#
# ground_truth: The referral is due to findings from an upper endoscopic biopsy which confirmed gastric cancer. Further staging with FDG-PET/CT has demonstrated not only increased FDG accumulation at the primary tumor site but also multiple metastatic intra-abdominal lymphadenopathies and a left supraclavicular lymph node. Additionally, there is widespread heterogeneous FDG uptake in the axial skeleton indicative of bone marrow involvement. The patient's hemoglobin was recorded at 9.5 g/dL, WBC at 4,100, and PLT at 33,000 per µL. A bone marrow biopsy has shown metastatic gastric cancer.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe requires a detailed genetic evaluation due to the presence of hereditary conditions identified in his family. His case involves specific genetic markers that need specialized examination and management.
#
# ground_truth: Mr. Doe requires a detailed genetic evaluation due to the presence of hereditary conditions identified in his family. His case involves specific genetic markers that need specialized examination and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient would benefit from a specialist's evaluation to better manage her recurrent endometriomas and assess her fertility options moving forward.
#
# ground_truth: She would benefit from a specialist's evaluation to better manage her recurrent endometriomas and assess her fertility options moving forward.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The purpose of this referral is to seek further expert consultation for continued management and potential additional corrective procedures to optimize the functional and aesthetic outcomes.
#
# ground_truth: The purpose of this referral is to seek further expert consultation for continued management and potential additional corrective procedures to optimize the functional and aesthetic outcomes.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to ensure the efficacy of the current AV synchrony and to further explore any underlying causes or potential need for additional adjustments to her device settings.
#
# ground_truth: The reason for this referral is to ensure the efficacy of the current AV synchrony and to further explore any underlying causes or potential need for additional adjustments to her device settings.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is the presence of pseudoexfoliation material (XFM) observed in the pupillary border and on the anterior surface of the intraocular lens (IOL) in her right eye. Given the potential complications associated with XFM, a comprehensive evaluation and management plan is warranted.
#
# ground_truth: The reason for this referral is the presence of pseudoexfoliation material (XFM) observed in the pupillary border and on the anterior surface of the intraocular lens (IOL) in her right eye. Given the potential complications associated with XFM, a comprehensive evaluation and management plan is warranted.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient needs to be referred for further evaluation of possible complications arising from the orthodontic appliance. We recommend a thorough assessment to rule out any underlying oral pathology or mechanical issues related to the metal brackets attached to the maxillary incisors.
#
# ground_truth: The patient needs to be referred for further evaluation of possible complications arising from the orthodontic appliance. We recommend a thorough assessment to rule out any underlying oral pathology or mechanical issues related to the metal brackets attached to the maxillary incisors.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The findings suggest the presence of a potentially obstructive lesion at the level of the foramen of Monro, necessitating further neurological evaluation and possible intervention. Your expertise in neurosurgery would be invaluable in determining the next steps for the patient's management.
#
# ground_truth: Referral Reason: The findings suggest the presence of a potentially obstructive lesion at the level of the foramen of Monro, necessitating further neurological evaluation and possible intervention. Your expertise in neurosurgery would be invaluable in determining the next steps for the patient's management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Ms. Doe exhibits three new formations of neurofibromatic masses on the left side of her palate and sublingual area as noted during her recent oral examination. These findings necessitate further specialized evaluation and management.
#
# ground_truth: Ms. Doe exhibits three new formations of neurofibromatic masses on the left side of her palate and sublingual area as noted during her recent oral examination. These findings necessitate further specialized evaluation and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for this referral is the diagnosis of neck metastasis with an unknown primary tumor. During a diagnostic flexible laryngoscopy, a small ulcerative lesion was observed on the laryngeal side of the epiglottis. Although an examination under general anesthesia did not reveal a malignancy, further specialized assessment and management are required to determine the primary tumor's origin and appropriate treatment protocol.
#
# ground_truth: The primary reason for this referral is the diagnosis of neck metastasis with an unknown primary tumor. During a diagnostic flexible laryngoscopy, a small ulcerative lesion was observed on the laryngeal side of the epiglottis. Although an examination under general anesthesia did not reveal a malignancy, further specialized assessment and management are required to determine the primary tumor's origin and appropriate treatment protocol.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the specificity and urgency of his condition, it is imperative that Mr. Doe receives further specialized retinal evaluation and appropriate management.
#
# ground_truth: Given the specificity and urgency of his condition, it is imperative that Mr. Doe receives further specialized retinal evaluation and appropriate management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is that Mr. Davis has developed persistent leukocytosis over the past 6 years while on his current medication. His medical history remains otherwise unremarkable.
#
# ground_truth: The reason for this referral is that Mr. Davis has developed persistent leukocytosis over the past 6 years while on his current medication. His medical history remains otherwise unremarkable.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: I believe further expertise is required to evaluate and manage the complications observed in cases of post-transplantation pulmonary alveolar proteinosis.
#
# ground_truth: I believe further expertise is required to evaluate and manage the complications observed in cases of post-transplantation pulmonary alveolar proteinosis.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe requires further orthopedic evaluation and management of his fractures and the damaged SSSC ring affecting three different regions. I would appreciate your expert attention and recommendations for his ongoing care.
#
# ground_truth: Mr. Doe requires further orthopedic evaluation and management of his fractures and the damaged SSSC ring affecting three different regions. I would appreciate your expert attention and recommendations for his ongoing care.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The histological findings will determine if there’s a need for further oncologic evaluation or treatment.
#
# ground_truth: The histological findings will determine if there’s a need for further oncologic evaluation or treatment.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe should be evaluated for possible surgical intervention to excise the calcified nodules, as they are numerous and cause significant discomfort. He does not have any systemic metabolic disorders, but the inflammation and rupture of the epidermoid cysts necessitate specialized care.
#
# ground_truth: Mr. Doe should be evaluated for possible surgical intervention to excise the calcified nodules, as they are numerous and cause significant discomfort. He does not have any systemic metabolic disorders, but the inflammation and rupture of the epidermoid cysts necessitate specialized care.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Currently, Mr. Doe is stable with no fever, abdominal pain, or jaundice. He requires further management and evaluation of potential surgical options for the removal of gallstones to prevent future episodes of pancreatitis.
#
# ground_truth: Referral Reason: Currently, Mr. Doe is stable with no fever, abdominal pain, or jaundice. He requires further management and evaluation of potential surgical options for the removal of gallstones to prevent future episodes of pancreatitis.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is recommended for further diagnostic evaluation and management of a suspected mandibular lesion. Given the size and duration of the swelling, as well as its radiographic appearance, a specialist's input is essential for accurate diagnosis and appropriate treatment planning.
#
# ground_truth: The referral is recommended for further diagnostic evaluation and management of a suspected mandibular lesion. Given the size and duration of the swelling, as well as its radiographic appearance, a specialist's input is essential for accurate diagnosis and appropriate treatment planning.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for this referral is the presence of a holosystolic murmur identified during her physical examination. The murmur is located between the S1 and S2 heart sounds and has frequency components extending to 600 Hz, as indicated by the spectrographic analysis. Given these findings, there is a high likelihood of serious cardiac implications that require a pediatric cardiologist's expertise for further diagnosis and treatment.
#
# ground_truth: The primary reason for this referral is the presence of a holosystolic murmur identified during her physical examination. The murmur is located between the S1 and S2 heart sounds and has frequency components extending to 600 Hz, as indicated by the spectrographic analysis. Given these findings, there is a high likelihood of serious cardiac implications that require a pediatric cardiologist's expertise for further diagnosis and treatment.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for this referral is the patient's complex vascular anatomy complicated by her age and cancer diagnosis. Treatment or management by a specialist in vascular surgery is advised.
#
# ground_truth: The primary reason for this referral is the patient's complex vascular anatomy complicated by her age and cancer diagnosis. Treatment or management by a specialist in vascular surgery is advised.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient requires a specialist consultation for further evaluation and possible alternative treatment options to effectively manage his persistent lesion. Given his unresponsive disease course to intralesional SSG therapy, advanced therapeutic strategies may be necessary.
#
# ground_truth: The patient requires a specialist consultation for further evaluation and possible alternative treatment options to effectively manage his persistent lesion. Given his unresponsive disease course to intralesional SSG therapy, advanced therapeutic strategies may be necessary.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for referral is the recent development of a red telangiectatic macula at the prior hemangioma site. Given the current response and the planned tapering off of Propranolol after she reaches 18 months of age, a specialist's opinion is required to ensure optimal long-term management.
#
# ground_truth: The reason for referral is the recent development of a red telangiectatic macula at the prior hemangioma site. Given the current response and the planned tapering off of Propranolol after she reaches 18 months of age, a specialist's opinion is required to ensure optimal long-term management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mrs. Doe requires further oncological assessment and potential adjuvant therapy given the clinical presentation and surgical findings. Despite the absence of tumor invasion into the fat, further evaluation is necessary to determine the appropriate course of post-surgical treatment.
#
# ground_truth: Referral Reason: Mrs. Doe requires further oncological assessment and potential adjuvant therapy given the clinical presentation and surgical findings. Despite the absence of tumor invasion into the fat, further evaluation is necessary to determine the appropriate course of post-surgical treatment.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Doe has been experiencing repeated right lower abdominal pain for the past 5 years. His medical history includes multiple visits to our hospital, during which standard treatments have provided only temporary relief. Given the chronic nature and persistence of his symptoms, we believe that specialized intervention is warranted.
#
# ...
#
# referral_content_prediction: The reason for this referral is to seek further evaluation and management of the patient's ectopic thyroid tissue and associated conditions, ensuring optimal intervention strategies.
#
# ground_truth: The reason for this referral is to seek further evaluation and management of the patient's ectopic thyroid tissue and associated conditions, ensuring optimal intervention strategies.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is the suspected serious interaction between melatonin and citalopram. Our tests have shown that melatonin products, including the one used by the patient, exhibit cytochrome P450 (CYP) 2C19 inhibitory activity in vitro. Given that citalopram is metabolized by CYP2C19, we suspect a combined pharmacodynamic and pharmacokinetic interaction, which has not been previously documented.
#
# ground_truth: The reason for this referral is the suspected serious interaction between melatonin and citalopram. Our tests have shown that melatonin products, including the one used by the patient, exhibit cytochrome P450 (CYP) 2C19 inhibitory activity in vitro. Given that citalopram is metabolized by CYP2C19, we suspect a combined pharmacodynamic and pharmacokinetic interaction, which has not been previously documented.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient presents with features suggestive of drusen, which mimic the appearance of true papilledema. Given the need for a thorough evaluation to rule out any misleading symptoms associated with such conditions, your expertise is highly sought.
#
# ground_truth: The patient presents with features suggestive of drusen, which mimic the appearance of true papilledema. Given the need for a thorough evaluation to rule out any misleading symptoms associated with such conditions, your expertise is highly sought.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is her persistent symptoms despite initial treatment, which suggest a potential underlying condition that requires further specialist assessment and management.
#
# ground_truth: The reason for this referral is her persistent symptoms despite initial treatment, which suggest a potential underlying condition that requires further specialist assessment and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Jane Doe was recently diagnosed with endometrial cancer at the age of 42. Given the significant family history of colorectal, endometrial, ovarian, and kidney cancers, I have conducted mismatch repair (MMR) analysis by immunohistochemistry on her tumor tissue. Due to these findings, I recommend a comprehensive review and potential genetic counseling to assess hereditary cancer risk.
#
# ground_truth: Jane Doe was recently diagnosed with endometrial cancer at the age of 42. Given the significant family history of colorectal, endometrial, ovarian, and kidney cancers, I have conducted mismatch repair (MMR) analysis by immunohistochemistry on her tumor tissue. Due to these findings, I recommend a comprehensive review and potential genetic counseling to assess hereditary cancer risk.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: On examination, Ms. Doe presented with a serous pigment epithelium detachment (PED) accompanied by subretinal hemorrhage and lipid exudation. Given the complexity and progression of her condition, I believe she would benefit from specialized ophthalmologic assessment and management.
#
# ground_truth: Given the complexity and progression of her condition, I believe she would benefit from specialized ophthalmologic assessment and management.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for referral is for a specialized ENT follow-up to ensure the proper healing of the endolaryngeal injury and to rule out any potential complications that may arise during the recovery period.
#
# ground_truth: The reason for referral is for a specialized ENT follow-up to ensure the proper healing of the endolaryngeal injury and to rule out any potential complications that may arise during the recovery period.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The primary reason for referral is the patient's persistent development of dermatological lesions following suspected contact with caterpillars. Despite initial treatment with betamethasone valerate 0.1% cream, the condition has not resolved entirely, and further specialist evaluation is warranted to rule out any potential secondary complications and to optimize treatment strategies.
#
# ground_truth: The primary reason for referral is the patient's persistent development of dermatological lesions following suspected contact with caterpillars. Despite initial treatment with betamethasone valerate 0.1% cream, the condition has not resolved entirely, and further specialist evaluation is warranted to rule out any potential secondary complications and to optimize treatment strategies.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral reason is the suspicion of an atrial mass. A recent CMR study showed extensive caseous calcification of the posterior mitral annulus, measuring 3 x 2.5 cm with a circumferential extension of about 5 cm. This mass is located in the basal inferior wall of the left ventricle, bulging into the posterior left atrium, but without significant mitral valve regurgitation.
#
# ground_truth: The referral reason is the suspicion of an atrial mass. A recent CMR study showed extensive caseous calcification of the posterior mitral annulus, measuring 3 x 2.5 cm with a circumferential extension of about 5 cm. This mass is located in the basal inferior wall of the left ventricle, bulging into the posterior left atrium, but without significant mitral valve regurgitation.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to seek your expert opinion and consider potential advanced therapeutic interventions that could assist in managing his PSP symptoms more effectively.
#
# ground_truth: The reason for this referral is to seek your expert opinion and consider potential advanced therapeutic interventions that could assist in managing his PSP symptoms more effectively.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is being made due to Mr. Doe's sustained neutropenia and newly developed eosinophilia.
#
# ground_truth: The referral is being made due to Mr. Doe's sustained neutropenia and newly developed eosinophilia. The patient was initially administered vancomycin, which was switched to ceftaroline due to an increase in serum creatinine. During the course of ceftaroline treatment, the patient became neutropenic and later developed eosinophilia, prompting a switch to daptomycin. His most recent WBC on day 14 was 2900 cells/mm3 with 61.4% neutrophils, indicating persistent neutropenia.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is the need for further investigation and specialized treatment of the friable mass, which was identified on colonoscopy. Biopsies of the mass revealed hyaline rings surrounding histiocytes or multinucleated giant cells along with vegetable debris, suggesting an unusual pathology that warrants further exploration by a specialist.
#
# ground_truth: The reason for this referral is the need for further investigation and specialized treatment of the friable mass, which was identified on colonoscopy. Biopsies of the mass revealed hyaline rings surrounding histiocytes or multinucleated giant cells along with vegetable debris, suggesting an unusual pathology that warrants further exploration by a specialist.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The imaging studies confirm the diagnosis of canal of Nuck hydrocele. The patient requires further evaluation and potential management by a pediatric surgeon to determine the appropriate treatment plan.
#
# ground_truth: The imaging studies confirm the diagnosis of canal of Nuck hydrocele. The patient requires further evaluation and potential management by a pediatric surgeon to determine the appropriate treatment plan.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Due to the incidental finding of the renal mass and subsequent confirmation of renal cell carcinoma, Mr. Doe requires specialized oncological assessment and potential follow-up treatments. Given his professional background and personal medical history, further evaluation and management by a renal cancer specialist are warranted to ensure optimal outcomes.
#
# ground_truth: Due to the incidental finding of the renal mass and subsequent confirmation of renal cell carcinoma, Mr. Doe requires specialized oncological assessment and potential follow-up treatments. Given his professional background and personal medical history, further evaluation and management by a renal cancer specialist are warranted to ensure optimal outcomes.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Due to the coexistence of DT and BCC in the histological findings and considering the patient's age and overall health, I recommend further dermatological surveillance to ensure there are no new or recurrent malignancies.
#
# ground_truth: Due to the coexistence of DT and BCC in the histological findings and considering the patient's age and overall health, I recommend further dermatological surveillance to ensure there are no new or recurrent malignancies.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The reason for this referral is to further evaluate and manage her recurrent respiratory infections and bronchiectasis. Given the frequency and severity of her symptoms, a comprehensive evaluation including imaging studies such as a CT scan is recommended to better understand her condition and guide future treatment strategies.
#
# ground_truth: The reason for this referral is to further evaluate and manage her recurrent respiratory infections and bronchiectasis. Given the frequency and severity of her symptoms, a comprehensive evaluation including imaging studies such as a CT scan is recommended to better understand her condition and guide future treatment strategies.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Mr. Smith's chronic eczema has not been responsive to over-the-counter topical treatments and requires specialized dermatological care. Given his complex medical history and the persistence of his symptoms, a comprehensive assessment and tailored treatment plan from your expertise are necessary.
#
# ground_truth: Mr. Smith's chronic eczema has not been responsive to over-the-counter topical treatments and requires specialized dermatological care. Given his complex medical history and the persistence of his symptoms, a comprehensive assessment and tailored treatment plan from your expertise are necessary.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is to ensure long-term management and to evaluate the potential need for future interventions to prevent recurrence. Your expertise would be greatly appreciated in providing a comprehensive treatment plan.
#
# ground_truth: The referral is to ensure long-term management and to evaluate the potential need for future interventions to prevent recurrence. Your expertise would be greatly appreciated in providing a comprehensive treatment plan.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is made due to the complexity of the tissue and bone damage which requires further specialized care, particularly for assessment of potential long-term functional impairment and additional reconstructive options.
#
# ground_truth: The referral is made due to the complexity of the tissue and bone damage which requires further specialized care, particularly for assessment of potential long-term functional impairment and additional reconstructive options.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The patient needs referral due to the presence of abnormal gender characteristics including microorchidism and mild bilateral gynecomastia. Additional specialized evaluation and management are crucial to address these endocrine issues.
#
# ground_truth: The patient needs referral due to the presence of abnormal gender characteristics including microorchidism and mild bilateral gynecomastia. Additional specialized evaluation and management are crucial to address these endocrine issues.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Given the neonatologist's suspicion of a congenital anal fissure, I would like to request your expert consultation to confirm the diagnosis and discuss potential management options.
#
# ground_truth: Given the neonatologist's suspicion of a congenital anal fissure, I would like to request your expert consultation to confirm the diagnosis and discuss potential management options.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: I am referring Mrs. Jane Doe, a 68-year-old woman, for further evaluation and management of her allergic reaction suspected to be due to hyaluronidase.
#
# ground_truth: I am referring Mrs. Jane Doe, a 68-year-old woman, for further evaluation and management of her allergic reaction suspected to be due to hyaluronidase.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: Despite the surgical intervention and current symptomatic improvement, recurrent episodes of oesophageal stricture and the underlying microcytic anaemia warrant further specialist evaluation. Comprehensive gastroenterological assessment and long-term management strategies are necessary to ensure the stability and overall well-being of the patient.
#
# ground_truth: Despite the surgical intervention and current symptomatic improvement, recurrent episodes of oesophageal stricture and the underlying microcytic anaemia warrant further specialist evaluation. Comprehensive gastroenterological assessment and long-term management strategies are necessary to ensure the stability and overall well-being of the patient.
# =============================
# is_papilledema_prediction: False
#
# referral_content_prediction: The referral is requested due to the patient's elevated serum ammonia levels (148 mcg/dl) following the increase of VPA to 1500 mg. Despite normal VPA levels (56.2 mg/L), he developed constipation and altered sensorium. Prompt discontinuation of VPA and initiation of lactulose resulted in his condition improving within 2 days. A gastroenterology consult was performed, but further specialist input is required to manage his elevated ammonia levels and ensure comprehensive care.
#
# ground_truth: The referral is requested due to the patient's elevated serum ammonia levels (148 mcg/dl) following the increase of VPA to 1500 mg. Despite normal VPA levels (56.2 mg/L), he developed constipation and altered sensorium. Prompt discontinuation of VPA and initiation of lactulose resulted in his condition improving within 2 days. A gastroenterology consult was performed, but further specialist input is required to manage his elevated ammonia levels and ensure comprehensive care.
# =============================
# CSV file has been saved to ./gemma_trainModel_result.csv

# %%
def analyze_predict_data(bleu_score_list):
    # 统计大于100的个数
    count_gt_100 = sum(1 for score in bleu_score_list if score >= 100)

    # 统计大于70的个数
    count_gt_70 = sum(1 for score in bleu_score_list if score > 70)

    prob_gt_100 = count_gt_100 / len(bleu_score_list)
    prob_gt_70 = count_gt_70 / len(bleu_score_list)
    average_score = sum(bleu_score_list) / float(len(bleu_score_list))

    print(f"分数大于100的个数：{count_gt_100}, 占所有数据的百分比为： {prob_gt_100}")
    print(f"分数大于70的个数：{count_gt_70}, 占所有数据的百分比为： {prob_gt_70}")
    print(f"bleu平均分数: {average_score}")

# %%
analyze_predict_data(bleu_score_list)

# %%
import sacrebleu
from rouge import Rouge
import pandas as pd
import re
import json

# def extract_content(response_text):
#     extract_array = response_text.split("###")
    
#     return extract_array[3]



    
def print_testjsonl_with_gemma(reference_path):
    
    test_data_json = []
    
    with open(reference_path, 'r', encoding='utf-8') as f:
        for line in f:
              test_data_json.append(json.loads(line.strip()))
    
    rouge_score_list = []
    bleu_score_list = []
              
    rouge = Rouge()
              
    prediction_list = []
              
    for single_test in test_data_json:
        instruction = single_test["instruction"]
        whole_letter = single_test["whole_letter"]
        referral_content = single_test["referral_content"]
        prompt = f"{instruction}\n\n###\n\n{whole_letter}\n\n###"
        response = fine_tuned_model.predict({'inputs': prompt, 'parameters': {'max_new_tokens': 256}})
        # response = origin_model.predict({prompt})

        reference_text = referral_content
        # print(response[0])
        try:
            # print("response: " + response)
            # response = reponse[0] if isinstance(response, list) else response
            # print("response: " + response)
            # prediction_dict = json.loads(response["generated_text"].strip())
            prediction_text = response[0]["generated_text"].strip()
            print(prediction_text + "\n")
            
            # extracted_referral_content = extract_content(prediction_text)
            # print(extracted_referral_content)
            
            # single_test["predict_referral_content"] = extracted_referral_content
           
          
        except Exception as err:
            prediction_text = "extract failure"
        finally:
            # prediction_list.append(extracted_referral_content)
            # print("prediction: " + extracted_referral_content + "\n")
            print("ground_truth: " + reference_text)
            print("=============================")

#         bleu_score = sacrebleu.corpus_bleu([extracted_referral_content], [[reference_text]])
#         bleu_score_list.append(bleu_score.score)
#         single_test["bleu"] = bleu_score.score

#         rouge_score = rouge.get_scores(extracted_referral_content, reference_text)
#         rouge_score_list.append(rouge_score)
        
        
        
#     # 创建 CSV 文件
#     csv_data = []

#     for single_test in test_data_json:
#         csv_data.append({
#             "id": single_test["id"],
#             "name": single_test["name"],
#             "instruction": single_test["instruction"],
#             "whole_letter": single_test["whole_letter"],
#             "referral_content": single_test["referral_content"],
#             "predict_referral_content": single_test["predict_referral_content"],
#             "bleu": single_test["bleu"],
#         })

#     # 创建 DataFrame
#     df = pd.DataFrame(csv_data)

#     # 保存为 CSV 文件
#     df.to_csv(csv_file_path, index=False, encoding='utf-8')

#     print(f"CSV file has been saved to {csv_file_path}")
        
#     return bleu_score_list

# %%
print_testjsonl_with_gemma("../test.jsonl")
# Out:
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# I am writing to refer Ms. Jane Doe, a 61-year-old woman who has presented with a 2-week history of progressive shortness of breath, non-productive cough, and lower extremity swelling.
#
# Patient Information:
# Name: Jane Doe
# Age: 61
# Gender: Female
# Symptoms: Shortness of breath, non-productive cough, lower extremity swelling
# Vital Signs: Tachycardia (114 beats per min), Tachypnea (28 breaths per min), Hypoxemia (88% SaO2 on room air)
# Physical Exam Findings: Jugular venous distention, bibasilar crackles, bilateral lower extremity pitting edema, apical holosystolic murmur with a mid-diastolic click
#
# The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# Dr. John Doe
#
# ###"is_Papilledema": False, "referral_content": "The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease."
#
# ground_truth: The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dr. John Smith,
# XYZ Hospital
#
# Dear Dr. Smith,
#
# I am writing to refer Mr. Robert Davis, a 75-year-old male, for further evaluation and management.
#
# **Patient Information:**
# Name: Robert Davis
# Age: 75 years
# Gender: Male
#
# Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement. Imaging studies including cervical spine radiograph, which showed apparent kyphosis, and MRI, which indicated no spinal cord compression, have been performed.
#
# Your expertise in this matter would be greatly appreciated.
#
# Sincerely,
# Dr. Emily Johnson
#
# ###"is_Papilledema": False, "referral_content": "Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement."
#
# ground_truth: Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement. Imaging studies including cervical spine radiograph, which showed apparent kyphosis, and MRI, which indicated no spinal cord compression, have been performed.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# Mr. John Doe, a 41-year-old male, presented to our clinic with a two-day history of low visual acuity in his right eye. Initial examination revealed that his visual acuity was at the level of counting fingers due to Valsalva retinopathy. Upon further investigation, we noted massive macular preretinal hemorrhage alongside scattered superior subretinal and intraretinal hemorrhages. Nd: YAG laser membranotomy was conducted, resulting in complete drainage of the preretinal blood, subsequently improving his visual acuity to 20/25.
#
# We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
#
# Thank you for your attention to this case.
#
# Sincerely,
#
# Dr. Jane Foster
#
# ###"is_Papilledema": False, "referral_content": "We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended."
#
# ground_truth: We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dr. John Smith,
# Pediatric Neurology Clinic,
# Main Street Hospital,
# 1234 Neurology Dr.
#
# Dear Dr. Smith,
#
# I hope this letter finds you well. I am writing to refer a patient, a 13-year-old boy named Jacob Martinez, who presented to our hospital with hemianopsia on the left side and increased intracranial pressure. An MRI revealed an expanded tumor that was encroaching on the third ventricle and posterior circulation, accompanied by hydrocephalus. We successfully removed the tumor via the orbitozygomatic approach, and Jacob is currently continuing his school life with hormone replacement therapy.
#
# The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
#
# Thank you for your attention to this matter. Please let me know if you require any further information.
#
# Best regards,
# Dr. Emily Johnson,
# Pediatric Surgery Department,
# City General Hospital
#
#
# ###"is_Papilledema": False, "referral_content": "The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively."
#
# ground_truth: The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# I am writing to refer Ms. Jane Doe, a 41-year-old female admitted to our center with complaints of right-sided upper abdominal pain. An ultrasound at her local institution revealed a mass in the right liver lobe, and her biochemical blood assay indicated increased levels of hepatic transaminases.
#
# Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
#
# Kindly find the attached patient details and preliminary tests for your review and further management.
#
# Sincerely,
# Dr. Green
# A.V. Vishnevsky National Medical Research Center of Surgery
#
# ###"is_Papilledema": False, "referral_content": "Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases."
#
# ground_truth: Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# I am writing to refer Patient A, a 45-year-old Caucasian male, for further consultation. He has no family history of cancer and is currently asymptomatic.
#
# Referral Reason: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# Dr. John Doe
#
# ###"is_Papilledema": False, "referral_content": "Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening."
#
# ground_truth: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dr. Smith,
#
# I hope this message finds you well. I am writing to refer Mr. John Doe, a 46-year-old male, for further evaluation.
#
# Mr. John Doe was initially diagnosed with pT2bN1 M0 melanoma of the right lower leg in February 2007. His treatment included excision, sentinel node sampling, inguinal dissection, and adjuvant interferon. In April 2008, he developed upper thigh in transit metastases and underwent radiotherapy, resulting in transient erythema and desquamation with resolution of all skin metastases. In December 2008, he developed a chest wall and lung metastases but achieved remission with no further systemic treatment.
#
# Referral Reason: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
#
# Thank you for your attention to this case.
#
# Best regards,
# Dr. Adams
#
# ###"is_Papilledema": False, "referral_content": "Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly."
#
# ground_truth: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Specialist,
#
# I am writing to refer Mr. John Doe, a 40-year-old male, diagnosed with type 2 diabetes mellitus (T2D) for the past 20 years. His medical history is significant for hypertension and hypercholesterolemia. His current medication regimen includes insulin glargine 58 units at bedtime, insulin aspart 22 units twice daily, canagliflozin 300 mg once daily, and metformin 1 g twice daily.
#
# The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
#
# Thank you for your attention to this matter. Please feel free to contact me if you need any further information.
#
# Best regards,
#
# Dr. Jane Smith
#
# ###"is_Papilledema": False, "referral_content": "The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes."
#
# ground_truth: The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Specialist,
#
# I hope this letter finds you well. I am writing to refer a patient who requires further evaluation and management.
#
# Name: Jane Doe
# Age: 63 years
# Gender: Female
#
# Reason for Referral: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# Dr. John Smith
#
# ###"is_Papilledema": False, "referral_content": "The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management."
#
# ground_truth: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# I am writing to refer Mr. John Doe, a 19-year-old male, for further evaluation and management.
#
# Mr. Doe presented to our outpatient clinic with gradually increased swelling in his right lower limb (RLL) for the past two weeks. He is currently employed as an accountant at a grocery shop and has a clear past medical and surgical history.
#
# Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
#
# Thank you for your attention to this matter.
#
# Sincerely,
# Dr. Jane Doe
#
# ###"is_Papilledema": False, "referral_content": "Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department."
#
# ground_truth: Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# To: Endocrinology Specialist
#
# Dear Colleague,
#
# I'd like to refer Mrs. Yoko Tanaka, a 56-year-old patient, for specialized follow-up care. Mrs. Tanaka recently underwent laparoscopic bilateral adrenalectomy due to overt symptoms of Cushing's syndrome caused by ACTH-independent macronodular adrenal hyperplasia (AIMAH), with suppressed serum ACTH levels and a disrupted cortisol circadian rhythm. She has been on cortisol replacement therapy since the surgery.
#
# Referral Reason: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
#
# Thank you for your attention to this patient. Please contact me if you need further information.
#
# Best Regards,
# Dr. Akira Sato
#
#
# ###
#
# "is_Papilledema": False, "referral_content": "Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed."
#
# ground_truth: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Colleague,
#
# I am writing to refer one of my patients for further specialized care.
#
# Patient Name: Mrs. Jane Doe
# Age: 67
# Gender: Female
# Medical History: Hospitalized for 1 month in ICU
# Diagnosis: Acute Respiratory Distress Syndrome (ARDS) caused by COVID-19
# Additional Findings: Secondary pneumonia
#
# The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended.
#
# Thank you for your attention to this matter.
#
# Best regards,
# Dr. John Smith
#
# ###"is_Papilledema": False, "referral_content": "The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended."
#
# ground_truth: The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Dr. Smith,
#
# I am writing to refer Emily Johnson, a five-year-old female, for further evaluation and possible intervention.
#
# Patient Information:
# Name: Emily Johnson
# Age: 5 years
# Gender: Female
#
# Emily was diagnosed with an involuted hemangioma of the upper lip. Following her diagnosis through preoperative Doppler ultrasonography, she underwent surgical excision. Postoperative follow-ups have shown a satisfactory appearance of the lip, and near-total remission of the lesion was confirmed on Doppler ultrasonography.
#
# Referral Reason: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
#
# I appreciate your attention to this case and anticipate your expert evaluation.
#
# Best regards,
# Dr. Alex Brown
#
# ###"is_Papilledema": False, "referral_content": "Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns."
#
# ground_truth: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
# =============================
# Synonyms: ["Papilledema","Swollen discs","Indistinct margins","Blurred disc margins","Suspicious discs","Disc swelling","Optic nerve swelling"]
#
# PseudoSynonyms: ["Pseudopapilledema","Drusen","Tilted disc","Anomalous discs"]
#
#
# Role : You are a experienced doctor who have memory of electronic medical records related to many diseases.
#
# Instruction : please extract the referral content from the following referral letter  separeted by ###.
#
# output your result directly in format: "is_Papilledema": boolean, "referral_content": "".
#
# Rule For is_Papilledema : If the referral letter contains one of words in Synonyms, then is_Papilledema = true; If the letter contains words in PseudoSynonyms or doesn't contain words in Synonyms, then is_Papilledema = False.
#
# Rule For referral_content : this content should be a whole paragraph which tells Patient need referral. If the referral_letter contains this content, you should include it. If the letter doesn't contain related information, then it should be null.
#
# ###
#
# Dear Colleague,
#
# I am writing to refer an 11-year-old male patient, John Doe, who has been experiencing repeated vomiting and headaches for the past month. Upon examination, he was found to have right-sided homonymous hemianopia and papilledema. Recent MRI revealed a ring-enhancing cystic mass lesion with perilesional edema in the left occipito-parietal region. Craniotomy was performed, and a high-grade glioma was excised. Histomorphological examination and immunohistochemistry findings are consistent with our pre-operative diagnosis.
#
# The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
#
# Thank you for your assistance.
#
# Sincerely,
# Dr. Jane Smith
#
# ###"is_Papilledema": False, "referral_content": "The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition."
#
# ground_truth: The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
# =============================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 print_testjsonl_with_gemma("../test.jsonl")
#
# Cell In[4], line 35, in print_testjsonl_with_gemma(reference_path)
#      33 referral_content = single_test["referral_content"]
#      34 prompt = f"{instruction}\n\n###\n\n{whole_letter}\n\n###"
# ---> 35 response = fine_tuned_model.predict({'inputs': prompt, 'parameters': {'max_new_tokens': 256}})
#      36 # response = origin_model.predict({prompt})
#      38 reference_text = referral_content
#
# File /opt/conda/lib/python3.10/site-packages/sagemaker/base_predictor.py:212, in Predictor.predict(self, data, initial_args, target_model, target_variant, inference_id, custom_attributes, component_name)
#     209 if inference_component_name:
#     210     request_args["InferenceComponentName"] = inference_component_name
# --> 212 response = self.sagemaker_session.sagemaker_runtime_client.invoke_endpoint(**request_args)
#     213 return self._handle_response(response)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:565, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     561     raise TypeError(
#     562         f"{py_operation_name}() only accepts keyword arguments."
#     563     )
#     564 # The "self" in this scope is referring to the BaseClient.
# --> 565 return self._make_api_call(operation_name, kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:1001, in BaseClient._make_api_call(self, operation_name, api_params)
#     997     maybe_compress_request(
#     998         self.meta.config, request_dict, operation_model
#     999     )
#    1000     apply_request_checksum(request_dict)
# -> 1001     http, parsed_response = self._make_request(
#    1002         operation_model, request_dict, request_context
#    1003     )
#    1005 self.meta.events.emit(
#    1006     'after-call.{service_id}.{operation_name}'.format(
#    1007         service_id=service_id, operation_name=operation_name
#    (...)
#    1012     context=request_context,
#    1013 )
#    1015 if http.status_code >= 300:
#
# File /opt/conda/lib/python3.10/site-packages/botocore/client.py:1027, in BaseClient._make_request(self, operation_model, request_dict, request_context)
#    1025 def _make_request(self, operation_model, request_dict, request_context):
#    1026     try:
# -> 1027         return self._endpoint.make_request(operation_model, request_dict)
#    1028     except Exception as e:
#    1029         self.meta.events.emit(
#    1030             'after-call-error.{service_id}.{operation_name}'.format(
#    1031                 service_id=self._service_model.service_id.hyphenize(),
#    (...)
#    1035             context=request_context,
#    1036         )
#
# File /opt/conda/lib/python3.10/site-packages/botocore/endpoint.py:119, in Endpoint.make_request(self, operation_model, request_dict)
#     113 def make_request(self, operation_model, request_dict):
#     114     logger.debug(
#     115         "Making request for %s with params: %s",
#     116         operation_model,
#     117         request_dict,
#     118     )
# --> 119     return self._send_request(request_dict, operation_model)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/endpoint.py:199, in Endpoint._send_request(self, request_dict, operation_model)
#     197 self._update_retries_context(context, attempts)
#     198 request = self.create_request(request_dict, operation_model)
# --> 199 success_response, exception = self._get_response(
#     200     request, operation_model, context
#     201 )
#     202 while self._needs_retry(
#     203     attempts,
#     204     operation_model,
#    (...)
#     207     exception,
#     208 ):
#     209     attempts += 1
#
# File /opt/conda/lib/python3.10/site-packages/botocore/endpoint.py:241, in Endpoint._get_response(self, request, operation_model, context)
#     235 def _get_response(self, request, operation_model, context):
#     236     # This will return a tuple of (success_response, exception)
#     237     # and success_response is itself a tuple of
#     238     # (http_response, parsed_dict).
#     239     # If an exception occurs then the success_response is None.
#     240     # If no exception occurs then exception is None.
# --> 241     success_response, exception = self._do_get_response(
#     242         request, operation_model, context
#     243     )
#     244     kwargs_to_emit = {
#     245         'response_dict': None,
#     246         'parsed_response': None,
#     247         'context': context,
#     248         'exception': exception,
#     249     }
#     250     if success_response is not None:
#
# File /opt/conda/lib/python3.10/site-packages/botocore/endpoint.py:281, in Endpoint._do_get_response(self, request, operation_model, context)
#     279     http_response = first_non_none_response(responses)
#     280     if http_response is None:
# --> 281         http_response = self._send(request)
#     282 except HTTPClientError as e:
#     283     return (None, e)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/endpoint.py:377, in Endpoint._send(self, request)
#     376 def _send(self, request):
# --> 377     return self.http_session.send(request)
#
# File /opt/conda/lib/python3.10/site-packages/botocore/httpsession.py:464, in URLLib3Session.send(self, request)
#     461     conn.proxy_headers['host'] = host
#     463 request_target = self._get_request_target(request.url, proxy_url)
# --> 464 urllib_response = conn.urlopen(
#     465     method=request.method,
#     466     url=request_target,
#     467     body=request.body,
#     468     headers=request.headers,
#     469     retries=Retry(False),
#     470     assert_same_host=False,
#     471     preload_content=False,
#     472     decode_content=False,
#     473     chunked=self._chunked(request.headers),
#     474 )
#     476 http_response = botocore.awsrequest.AWSResponse(
#     477     request.url,
#     478     urllib_response.status,
#     479     urllib_response.headers,
#     480     urllib_response,
#     481 )
#     483 if not request.stream_output:
#     484     # Cause the raw stream to be exhausted immediately. We do it
#     485     # this way instead of using preload_content because
#     486     # preload_content will never buffer chunked responses
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/lib/python3.10/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/lib/python3.10/http/client.py:1374, in HTTPConnection.getresponse(self)
#    1372 try:
#    1373     try:
# -> 1374         response.begin()
#    1375     except ConnectionError:
#    1376         self.close()
#
# File /opt/conda/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/conda/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/conda/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/conda/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# def analyze_predict_data(bleu_score_list):
#     # 统计大于100的个数
#     count_gt_100 = sum(1 for score in bleu_score_list if score >= 100)

#     # 统计大于70的个数
#     count_gt_70 = sum(1 for score in bleu_score_list if score > 70)

#     prob_gt_100 = count_gt_100 / len(bleu_score_list)
#     prob_gt_70 = count_gt_70 / len(bleu_score_list)
#     average_score = sum(bleu_score_list) / float(len(bleu_score_list))

#     print(f"分数大于100的个数：{count_gt_100}, 占所有数据的百分比为： {prob_gt_100}")
#     print(f"分数大于70的个数：{count_gt_70}, 占所有数据的百分比为： {prob_gt_70}")
#     print(f"bleu平均分数: {average_score}")

# %%
analyze_predict_data(bleu_score_list)

# %%
# import sacrebleu
# from rouge import Rouge


# import json

# def evaluate_testjsonl_with_gemma(path):
    
#     test_data_json = []
    
#     with open(path, 'r', encoding='utf-8') as f:
#         for line in f:
#               test_data_json.append(json.loads(line.strip()))
    
#     rouge_score_list = []
#     bleu_score_list = []
              
#     rouge = Rouge()
              
#     prediction_list = []
              
#     for single_test in test_data_json:
#         instruction = single_test["instruction"]
#         whole_letter = single_test["whole_letter"]
#         referral_content = single_test["referral_content"]
#         prompt = f"{instruction}\n\n###\n\n{whole_letter}\n\n###"
#         response = fine_tuned_model.predict({'inputs': prompt, 'parameters': {'max_new_tokens': 256}})
#         # response = fine_tuned_model.predict({prompt})

#         reference_text = referral_content
#         # print(response[0])
#         try:
#             # print("response: " + response)
#             # response = reponse[0] if isinstance(response, list) else response
#             # print("response: " + response)
#             # prediction_dict = json.loads(response["generated_text"].strip())
#             prediction_text = response[0]["generated_text"].strip()
#             # print(prediction_text)
#             # prediction_text = prediction_dict["referral_content"]
#         except Exception as err:
#             prediction_text = "extract failure"
#         finally:
#             prediction_list.append(prediction_text)
#             print("prediction: " + prediction_text)
#             print("ground_truth: " + reference_text)

#         bleu_score = sacrebleu.corpus_bleu([prediction_text], [[reference_text]])
#         bleu_score_list.append(bleu_score.score)

#         rouge_score = rouge.get_scores(prediction_text, reference_text)
#         rouge_score_list.append(rouge_score)
              
#     print(prediction_list)
#     print(rouge_score_list)
#     print(bleu_score_list)
