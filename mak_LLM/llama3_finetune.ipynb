# %% [markdown]
# # 部署训练好的LLAMA3model

# %%
from sagemaker.jumpstart.estimator import JumpStartEstimator

training_job_name = "llama-3-mak-10-epochs"
model_id = "meta-textgeneration-llama-3-8b-instruct"

model = JumpStartEstimator.attach(training_job_name, model_id)
# attached_estimator.logs()
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/sagemaker-user/.config/sagemaker/config.yaml
# Using model 'meta-textgeneration-llama-3-8b-instruct' with wildcard version identifier '*'. You can pin to version '2.0.2' for more stable results. Note that models may have different input/output signatures after a major version upgrade.
# 2024-07-29 18:24:56 Starting - Preparing the instances for training
# 2024-07-29 18:24:56 Downloading - Downloading the training image
# 2024-07-29 18:24:56 Training - Training image download completed. Training in progress.
# 2024-07-29 18:24:56 Uploading - Uploading generated training model
# 2024-07-29 18:24:56 Completed - Training job completed

# %%
instance_type="ml.g5.2xlarge"
predictor = model.deploy(instance_type=instance_type)
# Out:
# ----------------!

# %%
with open("letter.txt", "r", encoding="utf-8") as f:
    letter = f.read()
# print(letter)

response = predictor.predict({'inputs': letter,
                             'parameters': {'max_new_tokens': 128}})
response = response[0] if isinstance(response, list) else response

print("Output:\n", response["generated_text"].strip(), end="\n\n\n")
# Out:
# Output:
#  ### Response:
# "is_Papilledema": False, "referral_content": "Despite adherence to current treatment protocols and lifestyle modifications, Mr. Clark's symptoms have progressively worsened. His recent spirometry results indicate a significant decline in pulmonary function, suggestive of potential chronic obstructive pulmonary disease (COPD) exacerbation."

# %%
# !pip install nltk sacrebleu
# !pip install rouge
# Out:
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (3.8.1)
# Collecting sacrebleu
#   Using cached sacrebleu-2.4.2-py3-none-any.whl.metadata (58 kB)
# Requirement already satisfied: click in /opt/conda/lib/python3.10/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from nltk) (4.66.4)
# Collecting portalocker (from sacrebleu)
#   Using cached portalocker-2.10.1-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.9.0)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (0.4.6)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from sacrebleu) (4.9.4)
# Using cached sacrebleu-2.4.2-py3-none-any.whl (106 kB)
# Using cached portalocker-2.10.1-py3-none-any.whl (18 kB)
# Installing collected packages: portalocker, sacrebleu
# Successfully installed portalocker-2.10.1 sacrebleu-2.4.2
# Collecting rouge
#   Using cached rouge-1.0.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from rouge) (1.16.0)
# Using cached rouge-1.0.1-py3-none-any.whl (13 kB)
# Installing collected packages: rouge
# Successfully installed rouge-1.0.1

# %%
import sacrebleu

# 参考文本（字符串）
reference_text = "The patient is referred due to the rapid progression of the tumor despite initial treatment modalities. Further evaluation and management from a specialized neuro-oncology team are essential for this recurrent and aggressive tumor."

# 生成的文本（字符串）
candidate_text = "The patient is referred due to the rapid progression of the tumor despite initial treatment modalities. Further evaluation and management from a specialized neuro-oncology team are essential for this recurrent and aggressive tumor."

# 计算BLEU分数，调整n-gram权重
# 默认权重是(0.25, 0.25, 0.25, 0.25)，分别对应1-gram到4-gram
# 我们可以调整权重，例如只考虑1-gram和2-gram，权重分别为(0.5, 0.5)
# 设置n-gram权重
weights = (0.5, 0.5, 0, 0)

# 创建BLEU对象，并传入自定义的权重
weights = (0.5, 0.5, 0, 0)

bleu = sacrebleu.corpus_bleu([candidate_text], [[reference_text]])
print(f"BLEU score (): {bleu.score}")
print(bleu)
# Out:
# BLEU score (): 100.00000000000004
# BLEU = 100.00 100.0/100.0/100.0/100.0 (BP = 1.000 ratio = 1.000 hyp_len = 35 ref_len = 35)

# %%
from rouge import Rouge

# 计算ROUGE分数
rouge = Rouge()
scores = rouge.get_scores(candidate_text, reference_text, avg=True) # 由于只有一个 reference，所以 avg没有影响
print(f"ROUGE scores: {scores}")
# Out:
# ROUGE scores: {'rouge-1': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-2': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}, 'rouge-l': {'r': 1.0, 'p': 1.0, 'f': 0.999999995}}

# %%
import sacrebleu
from rouge import Rouge

import json
import pandas as pd

import re

def replace_output_prefix(input_str):
    # 使用正则表达式进行替换，忽略大小写
    result = re.sub(r'(?i)^Output:\s*', '', input_str)
    return result


def extract_braced_content(input_str):
    # 使用正则表达式提取大括号及其内的内容
    match = re.search(r'\{[^{}]*\}', input_str)
    if match:
        # 返回包含大括号及其内容的匹配部分
        return match.group(0)
    else:
        # 如果没有匹配到内容，返回空字符串或其他标记
        return ''


def extract_referral_content_original(data_str):
    # 使用正则表达式提取referral_content的内容
    match = re.search(r'"referral_content":\s*(null|".*?")', data_str)
    if match:
        content = match.group(1)
        if content == "null":
            return ""
        else:
            # 去掉引号
            return content.strip('"')
    return ''


def extract_referral_content(data_str):
    # 使用正则表达式提取referral_content的内容
    match = re.search(r'"referral_content":\s*"(.*?)"', data_str)
    if match:
        return match.group(1)
    return ''
    

def evaluate_jsonl_with_llama3(predictor, path, csv_file_path):
    test_data_json = []
    with open(path, 'r', encoding='utf-8') as f:
        for line in f:
            test_data_json.append(json.loads(line.strip()))
    rouge_score_list = []
    bleu_score_list = []

    rouge = Rouge()

    evaluate_list = []

    for single_test in test_data_json:
        instruction = single_test["instruction"]
        whole_letter = single_test["whole_letter"]
        referral_content = single_test["referral_content"]
        prompt = f"{instruction}\n\n###\n\n{whole_letter}\n\n###"
        response = predictor.predict({'inputs': prompt, 'parameters': {'max_new_tokens': 128}})
        # print(prompt)
        print("----------------------------------------------------------------")

        response = response[0] if isinstance(response, list) else response
        # print("Output:\n", response["generated_text"].strip(), end="\n\n\n")

        reference_text = referral_content
        try:
            tmp_str = replace_output_prefix(response["generated_text"].strip())
            # print(tmp_str)
            # tmp_str = extract_braced_content(tmp_str)
            # # print(tmp_str)
            tmp = extract_referral_content(tmp_str)
            # print(tmp)
            candidate_text = tmp
        except Exception as err:
            # print(single_test["id"])
            # print(response["generated_text"].strip())
            # print()
            candidate_text = "extract failure"
        finally:

            evaluate_list.append(candidate_text)
            print("predict: " + candidate_text)
            print("real: " + reference_text)


            bleu = sacrebleu.corpus_bleu([candidate_text], [[reference_text]])
            bleu_score_list.append(bleu.score)
            print(bleu.score)
            single_test["bleu"] = bleu.score
            single_test["predict_referral_content"] = candidate_text
            print()
            
            # 计算ROUGE分数
            # scores = rouge.get_scores(candidate_text, reference_text) # 由于只有一个 reference，所以 avg没有影响
            # rouge_score_list.append(scores)
            
#     with open(output_jsonl_path, mode='w', encoding='utf-8') as f:
#         for single_test in test_data_json:
#             f.write(json.dumps(single_test, ensure_ascii=False) + '\n')

#     print(f"predicted data has been saved to {output_path}.")
    
    # 创建 CSV 文件
    csv_data = []

    for single_test in test_data_json:
        csv_data.append({
            # "id": single_test["id"],
            # "name": single_test["name"],
            "instruction": single_test["instruction"],
            "whole_letter": single_test["whole_letter"],
            "referral_content": single_test["referral_content"],
            "predict_referral_content": single_test["predict_referral_content"],
            "bleu": single_test["bleu"],
        })

    # 创建 DataFrame
    df = pd.DataFrame(csv_data)

    # 保存为 CSV 文件
    df.to_csv(csv_file_path, index=False, encoding='utf-8')

    print(f"CSV file has been saved to {csv_file_path}")
    
    return evaluate_list, bleu_score_list, rouge_score_list

# %%
test_evaluate_list, test_bleu_score_list, test_rouge_score_list = evaluate_jsonl_with_llama3(predictor, "test_data_735/test.jsonl", "llama3_funetune_test.csv")
# Out:
# ----------------------------------------------------------------
# predict: The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
# real: The reason for this referral is to further evaluate and manage Ms. Jane Doe's progressively worsening cardiopulmonary symptoms. Given her clinical presentation, further investigation is essential to rule out possible cardiac etiologies, including congestive heart failure or valvular disease.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement. Imaging studies including cervical spine radiograph, which showed apparent kyphosis, and MRI, which indicated no spinal cord compression, have been performed.
# real: Mr. Davis has presented with significant neck pain and dropped head syndrome without any neurological abnormalities. Despite physical therapy, including cervical spine traction and extensor muscle training, there has been no improvement. Imaging studies including cervical spine radiograph, which showed apparent kyphosis, and MRI, which indicated no spinal cord compression, have been performed.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
# real: We are referring Mr. Doe to your care to ensure further monitoring and management of his condition, as follow-up evaluations and potential treatments may be necessary. His central macula is now clear of subretinal hemorrhage, but continued oversight by a specialist in retinal conditions is highly recommended.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
# real: The reason for this referral is for a comprehensive follow-up and ongoing management of Jacob’s condition. He requires specialized pediatric neurological oversight to monitor his recovery post-tumor resection and to manage his hormone replacement therapy effectively.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
# real: Given the imaging and laboratory findings, further diagnostic evaluation and potential therapeutic intervention from a hepatologist are recommended to determine the nature of the liver mass and address the elevated hepatic transaminases.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
# real: Given the differing recommendations regarding PSA-based screening for prostate cancer, we believe it is in the best interest of Patient A to have a thorough discussion with a specialist. This will allow him to make an informed decision regarding the risks and benefits of PSA-based screening.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
# real: Due to the history of recurrent metastatic melanoma and the need for an expert follow-up, I am referring Mr. John Doe for a comprehensive oncological evaluation to ensure continued remission and address any potential recurrence promptly.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
# real: The referral is being made for the evaluation and management of potential diabetic neuropathy. Over the past few months, Mr. Doe has been experiencing increasing numbness and tingling in his lower extremities, which raises concern for this complication of diabetes.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
# real: The patient, Jane Doe, presents with a history of basal cell carcinoma on the front of her scalp, initially diagnosed 5 years ago. After surgical excision and subsequent skin grafting, the patient has had a satisfactory recovery. However, given her history and the potential for recurrence or complications, further specialist evaluation is warranted to ensure comprehensive long-term management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
# real: Given the persistent and progressive nature of the swelling, I am concerned about potential underlying vascular pathology. He would benefit from a comprehensive evaluation and appropriate management by a specialist in your esteemed department.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
# real: Mrs. Tanaka requires further endocrinological evaluation and management to ensure the adequacy of her cortisol replacement therapy and to monitor for any potential complications following bilateral adrenalectomy. Additionally, ongoing monitoring of her diabetes mellitus and hypertension in the context of her altered hormonal status is needed.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: The reason for this referral is that Mrs. Doe developed ARDS secondary to COVID-19, along with secondary pneumonia. Given the complexity of her case, especially with the prolonged ICU stay and multi-organ involvement, further expert management is recommended.
# 0.0
#
# ----------------------------------------------------------------
# predict: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
# real: Given the successful surgical outcome, I recommend further evaluation to ensure complete remission and discuss any additional treatment options that may be necessary to prevent recurrence and address any residual aesthetic concerns.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
# real: The patient requires further specialized oncological assessment and potential adjunct therapies to ensure complete management of his condition.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: I am writing to refer Mrs. Lisa Thompson, a 52-year-old female patient under my care, to your cardiology clinic for further evaluation and management.
# real: Mrs. Thompson has been experiencing frequent episodes of chest pain and shortness of breath over the past three months. Despite initial management with beta-blockers, there has been minimal improvement. Her recent EKG showed nonspecific ST-segment changes, raising concerns for underlying ischemic heart disease.
# 1.9196616846685577
#
# ----------------------------------------------------------------
# predict: Despite the successful placement of the gingiva-colored restorations, the patient continues to experience persistent sensitivity in the left maxillary region, suggesting the potential for an underlying issue that requires further evaluation and management by a specialist.
# real: Despite the successful placement of the gingiva-colored restorations, the patient continues to experience persistent sensitivity in the left maxillary region, suggesting the potential for an underlying issue that requires further evaluation and management by a specialist.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: The reason for this referral is to seek your specialized assistance in the management of her persistent skin problems attributed to excess overhanging skin. While an infraumbilical panniculectomy with umbilical transposition had been previously performed, her skin issues necessitate further evaluation and potential intervention.
# 0.0
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to seek your expertise in developing a long-term oncological surveillance and management plan for Mr. Doe, given his high-grade urothelial carcinoma and previous surgical interventions.
# real: The reason for this referral is to seek your expertise in developing a long-term oncological surveillance and management plan for Mr. Doe, given his high-grade urothelial carcinoma and previous surgical interventions.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the persistence of her symptoms despite treatment, I am concerned that there may be an underlying condition that requires further specialized investigation.
# real: Given the persistence of her symptoms despite treatment, I am concerned that there may be an underlying condition that requires further specialized investigation.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the complexity of Mrs. Smith's ocular conditions and her recent improvement, she requires specialized follow-up to optimize her visual outcome and monitor for potential recurrence or complications.
# real: Given the complexity of Mrs. Smith's ocular conditions and her recent improvement, she requires specialized follow-up to optimize her visual outcome and monitor for potential recurrence or complications.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is for further evaluation and management of her diabetes, as she has shown an initial response to sitagliptin but has had a slight weight gain of 1kg. Her fructosamine levels have decreased significantly, showing a reduction equivalent to a 0.3% and 1.2% decrease in HbA1c at 6 and 12 months, respectively. However, additional expertise in diabetes management may be beneficial for optimizing her treatment and preventing further complications.
# real: The referral is for further evaluation and management of her diabetes, as she has shown an initial response to sitagliptin but has had a slight weight gain of 1kg. Her fructosamine levels have decreased significantly, showing a reduction equivalent to a 0.3% and 1.2% decrease in HbA1c at 6 and 12 months, respectively. However, additional expertise in diabetes management may be beneficial for optimizing her treatment and preventing further complications.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is necessary to ensure the continued monitoring and management of her facial scarring, to evaluate the long-term effectiveness of the fat injections, and to discuss potential adjunctive treatments if required.
# real: The referral is necessary to ensure the continued monitoring and management of her facial scarring, to evaluate the long-term effectiveness of the fat injections, and to discuss potential adjunctive treatments if required.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Doe requires a specialist evaluation for the confirmed diagnosis and management of his onychomycosis. Given its persistence and unresponsiveness to initial therapies, a specialist's insights are imperative for targeted treatment.
# real: Mr. Doe requires a specialist evaluation for the confirmed diagnosis and management of his onychomycosis. Given its persistence and unresponsiveness to initial therapies, a specialist's insights are imperative for targeted treatment.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: Referral is being sought for further evaluation and management due to the initial severity of the condition and to ensure ongoing stability given her medical history.
# 0.0
#
# ----------------------------------------------------------------
# predict: The referral reason is the need for specialized post-operative care following a recent VATS lobectomy. Despite a relatively stable post-operative course, Mr. Doe's complex medical history necessitates continued expert assessment to optimize his recovery and manage any potential complications.
# real: The referral reason is the need for specialized post-operative care following a recent VATS lobectomy. Despite a relatively stable post-operative course, Mr. Doe's complex medical history necessitates continued expert assessment to optimize his recovery and manage any potential complications.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Doe presented with ulcers on the left buccal mucosa in the regions corresponding to teeth 35, 36, and 37. The ulcers measure approximately 4 cm by 3 cm, are irregular in shape, exhibit punched-out borders with tissue tags, and are surrounded by inflammation. Additionally, a similar ulcer is present in the right buccal mucosa in the regions corresponding to teeth 45, 46, and 47. The differential diagnosis includes a traumatic ulcer secondary to cheek bite.
# real: Further evaluation from a specialist is necessary to confirm the diagnosis and to establish an appropriate management plan for Mr. Doe's oral ulcers.
# 1.2376649122274905
#
# ----------------------------------------------------------------
# predict: The referral is necessitated by Ms. Doe’s significant reaction to the blue dye, including a recorded 6 mm positive reaction on skin prick test (SPT) with patent blue V, while having no previous history of allergy or atopy. Her peak MCT levels rose to 12.1 ng/mL post-reaction, markedly higher than her baseline of 3.2 ng/mL. This suggests the possibility of a specific allergy that needs further investigation and management.
# real: The referral is necessitated by Ms. Doe’s significant reaction to the blue dye, including a recorded 6 mm positive reaction on skin prick test (SPT) with patent blue V, while having no previous history of allergy or atopy. Her peak MCT levels rose to 12.1 ng/mL post-reaction, markedly higher than her baseline of 3.2 ng/mL. This suggests the possibility of a specific allergy that needs further investigation and management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is specifically for a detailed otologic and neurologic evaluation. Intense postFLAIR-enhancement was observed in the cochlea, vestibule, and semicircular canal, along with significant enhancement involving the cochlear nerve. This suggests potential complications that require specialist input.
# real: The referral is specifically for a detailed otologic and neurologic evaluation. Intense postFLAIR-enhancement was observed in the cochlea, vestibule, and semicircular canal, along with significant enhancement involving the cochlear nerve. This suggests potential complications that require specialist input.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for the referral is to ensure specialized perioperative care, considering her multiple drug allergies and her requirement for a total thyroidectomy. She needs thorough preoperative evaluation and management from a multidisciplinary team aimed at minimizing the risk of allergic reactions.
# real: The reason for the referral is to ensure specialized perioperative care, considering her multiple drug allergies and her requirement for a total thyroidectomy. She needs thorough preoperative evaluation and management from a multidisciplinary team aimed at minimizing the risk of allergic reactions.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to ensure Mr. Doe receives comprehensive post-discharge care, focusing on the management and follow-up of his multiple chronic conditions, especially given his recent COVID-19 infection.
# real: The reason for this referral is to ensure Mr. Doe receives comprehensive post-discharge care, focusing on the management and follow-up of his multiple chronic conditions, especially given his recent COVID-19 infection.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: We are referring Ms. Doe to your esteemed clinic for further evaluation and management of her large hiatal hernia and potential complications from the extrinsic mass compressing the left atrium. Due to the complexity of her condition, specialized assessment and treatment are necessary to ensure her well-being.
# real: We are referring Ms. Doe to your esteemed clinic for further evaluation and management of her large hiatal hernia and potential complications from the extrinsic mass compressing the left atrium. Due to the complexity of her condition, specialized assessment and treatment are necessary to ensure her well-being.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to obtain specialized orthopedic evaluation and further management for Ms. Doe’s left tibial plateau fracture and associated injuries.
# real: The reason for this referral is to obtain specialized orthopedic evaluation and further management for Ms. Doe’s left tibial plateau fracture and associated injuries.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Smith requires specialized orthopedic evaluation to confirm the diagnosis of osteonecrosis of the lunate and to develop an appropriate treatment plan, including the potential need for surgical intervention.
# real: Mr. Smith requires specialized orthopedic evaluation to confirm the diagnosis of osteonecrosis of the lunate and to develop an appropriate treatment plan, including the potential need for surgical intervention.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the acute onset of altered sensorium and persistent fever, a more comprehensive neurological evaluation is warranted to rule out potential central nervous system infections or other neurological conditions. Your expertise is essential in further diagnostic workup and management.
# real: Given the acute onset of altered sensorium and persistent fever, a more comprehensive neurological evaluation is warranted to rule out potential central nervous system infections or other neurological conditions. Your expertise is essential in further diagnostic workup and management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the complexity and range of his symptoms, I believe a specialist’s evaluation is warranted to determine the underlying cause and appropriate treatment plan.
# real: Given the complexity and range of his symptoms, I believe a specialist’s evaluation is warranted to determine the underlying cause and appropriate treatment plan.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is sought to investigate and manage the ongoing complications resulting from the infection and subsequent surgeries, specifically the air leak and confirmed AEF.
# real: The referral is sought to investigate and manage the ongoing complications resulting from the infection and subsequent surgeries, specifically the air leak and confirmed AEF.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is her complex symptomatology and the need for further specialized evaluation to determine any underlying genetic conditions that might explain her physical anomalies and epilepsy.
# real: The reason for this referral is her complex symptomatology and the need for further specialized evaluation to determine any underlying genetic conditions that might explain her physical anomalies and epilepsy.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for referral is to seek advanced evaluation and management options given the patient's high Gleason score and significant PSA levels. A whole body Ga-68 PSMA PET/CT for staging showed an enhancing lesion in the prostate gland with a maximum standardized uptake value (SUVmax) of 16 and thickening of the entire shaft of the penis with intense PSMA uptake (SUVmax of 35). He has undergone bilateral orchidectomy and radiotherapy but requires ongoing specialized follow-up.
# real: The reason for referral is to seek advanced evaluation and management options given the patient's high Gleason score and significant PSA levels.
# 26.02770581635138
#
# ----------------------------------------------------------------
# predict: The referral reason is the noted proptosis of uncertain duration and significant imaging findings suggestive of an underlying inflammatory or infiltrative process. Further specialist input is required to determine the precise diagnosis and appropriate care plan.
# real: The referral reason is the noted proptosis of uncertain duration and significant imaging findings suggestive of an underlying inflammatory or infiltrative process. Further specialist input is required to determine the precise diagnosis and appropriate care plan.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Smith requires further oncologic evaluation and management of transitional cell carcinoma. Your expert assessment and recommendations for the most appropriate therapeutic options will be greatly appreciated.
# real: Mr. Smith requires further oncologic evaluation and management of transitional cell carcinoma. Your expert assessment and recommendations for the most appropriate therapeutic options will be greatly appreciated.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Smith requires further evaluation and specialized management to ascertain the nature of this mass and appropriate treatment.
# real: Mr. Smith requires further evaluation and specialized management to ascertain the nature of this mass and appropriate treatment.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to ensure ongoing specialized care and follow-up management. Mr. Doe's complex medical history and recent surgical intervention warrant continued surveillance by a specialist in this field.
# real: The reason for this referral is to ensure ongoing specialized care and follow-up management. Mr. Doe's complex medical history and recent surgical intervention warrant continued surveillance by a specialist in this field.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Ms. Doe requires further evaluation and possible intervention for the cystic tumor in her mediastinum. Given its size and location, your expertise in thoracic oncology would be greatly valuable in determining the appropriate course of action.
# real: Ms. Doe requires further evaluation and possible intervention for the cystic tumor in her mediastinum. Given its size and location, your expertise in thoracic oncology would be greatly valuable in determining the appropriate course of action.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for referral is for specialized management of Mr. Smith’s postoperative progress and any further necessary interventions to optimize recovery. Your expertise will be invaluable in ensuring his continued improvement and addressing any potential complications.
# real: The primary reason for referral is for specialized management of Mr. Smith’s postoperative progress and any further necessary interventions to optimize recovery. Your expertise will be invaluable in ensuring his continued improvement and addressing any potential complications.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Doe requires further specialized assessment and management of his deteriorating liver function and ongoing vision and hearing impairment. Immediate evaluation by a hepatic specialist and a neurologist is highly recommended to address these issues comprehensively.
# real: Mr. Doe requires further specialized assessment and management of his deteriorating liver function and ongoing vision and hearing impairment. Immediate evaluation by a hepatic specialist and a neurologist is highly recommended to address these issues comprehensively.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: Mrs. Johnson has been struggling with Generalized Granuloma Annulare (GGA) for the past five years. Despite various topical treatments, including pimecrolimus 0.1% cream, triamcinolone 0.5% cream, desoximetasone 0.25% cream, and flurandrenolide tape, she has only experienced mild improvements. A three-month course of pentoxifylline and oral vitamin E provided some benefits, particularly noticeable in her distal upper extremities. I am referring her to you for further evaluation and potential advanced therapies.
# 0.0
#
# ----------------------------------------------------------------
# predict: Given the findings of hepatitis and membrano-proliferative glomerulonephritis, I believe further specialist evaluation is required to manage his condition effectively.
# real: Given the findings of hepatitis and membrano-proliferative glomerulonephritis, I believe further specialist evaluation is required to manage his condition effectively.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The purpose of this referral is for specialized cardiological evaluation and management. Given the complex nature of her cardiac anomalies and symptoms, she would benefit immensely from your expertise.
# real: The purpose of this referral is for specialized cardiological evaluation and management. Given the complex nature of her cardiac anomalies and symptoms, she would benefit immensely from your expertise.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to ensure comprehensive follow-up and monitoring for any potential complications related to the Anisakis simplex infection, as well as to prevent recurrence and manage any residual gastrointestinal symptoms. A specialist's opinion and further endoscopic evaluation may be warranted.
# real: The reason for this referral is to ensure comprehensive follow-up and monitoring for any potential complications related to the Anisakis simplex infection, as well as to prevent recurrence and manage any residual gastrointestinal symptoms. A specialist's opinion and further endoscopic evaluation may be warranted.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is necessary due to the unusual arrangement of the piriformis muscle and the early splitting of the left sciatic nerve, where the common peroneal component passes through the two heads of the piriformis muscle. This configuration may have clinical implications that warrant further investigation by a specialist.
# real: The referral is necessary due to the unusual arrangement of the piriformis muscle and the early splitting of the left sciatic nerve, where the common peroneal component passes through the two heads of the piriformis muscle. This configuration may have clinical implications that warrant further investigation by a specialist.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for this referral is the patient's chronic and poorly controlled hypertension, which has not responded adequately to multiple antihypertensive medications. Despite adherence to a comprehensive treatment plan encompassing lifestyle modifications and pharmacological therapy, Mr. Doe continues to experience elevated blood pressure readings, averaging 160/100 mmHg over the past three months. This is concerning given his increased risk for cardiovascular events and organ damage.
# real: The primary reason for this referral is the patient's chronic and poorly controlled hypertension, which has not responded adequately to multiple antihypertensive medications. Despite adherence to a comprehensive treatment plan encompassing lifestyle modifications and pharmacological therapy, Mr. Doe continues to experience elevated blood pressure readings, averaging 160/100 mmHg over the past three months. This is concerning given his increased risk for cardiovascular events and organ damage.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral reason is the confirmed diagnosis of isolated cardiac apical cystic echinococcosis in the left ventricular apex detected via echocardiography and confirmed by computed tomography. Despite being recommended for surgery, the patient has refused the operation.
# real: The referral reason is the confirmed diagnosis of isolated cardiac apical cystic echinococcosis in the left ventricular apex detected via echocardiography and confirmed by computed tomography. Despite being recommended for surgery, the patient has refused the operation.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: The referral is due to findings from an upper endoscopic biopsy which confirmed gastric cancer. Further staging with FDG-PET/CT has demonstrated not only increased FDG accumulation at the primary tumor site but also multiple metastatic intra-abdominal lymphadenopathies and a left supraclavicular lymph node. Additionally, there is widespread heterogeneous FDG uptake in the axial skeleton indicative of bone marrow involvement. The patient's hemoglobin was recorded at 9.5 g/dL, WBC at 4,100, and PLT at 33,000 per µL. A bone marrow biopsy has shown metastatic gastric cancer.
# 0.0
#
# ----------------------------------------------------------------
# predict: Mr. Doe requires a detailed genetic evaluation due to the presence of hereditary conditions identified in his family. His case involves specific genetic markers that need specialized examination and management.
# real: Mr. Doe requires a detailed genetic evaluation due to the presence of hereditary conditions identified in his family. His case involves specific genetic markers that need specialized examination and management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient was later hospitalized with an 8 cm pelvic abscess, which required surgical drainage after her condition improved with intravenous antibiotics. She would benefit from a specialist's evaluation to better manage her recurrent endometriomas and assess her fertility options moving forward.
# real: She would benefit from a specialist's evaluation to better manage her recurrent endometriomas and assess her fertility options moving forward.
# 44.76855893974308
#
# ----------------------------------------------------------------
# predict: The purpose of this referral is to seek further expert consultation for continued management and potential additional corrective procedures to optimize the functional and aesthetic outcomes.
# real: The purpose of this referral is to seek further expert consultation for continued management and potential additional corrective procedures to optimize the functional and aesthetic outcomes.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to ensure the efficacy of the current AV synchrony and to further explore any underlying causes or potential need for additional adjustments to her device settings.
# real: The reason for this referral is to ensure the efficacy of the current AV synchrony and to further explore any underlying causes or potential need for additional adjustments to her device settings.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is the presence of pseudoexfoliation material (XFM) observed in the pupillary border and on the anterior surface of the intraocular lens (IOL) in her right eye. Given the potential complications associated with XFM, a comprehensive evaluation and management plan is warranted.
# real: The reason for this referral is the presence of pseudoexfoliation material (XFM) observed in the pupillary border and on the anterior surface of the intraocular lens (IOL) in her right eye. Given the potential complications associated with XFM, a comprehensive evaluation and management plan is warranted.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient needs to be referred for further evaluation of possible complications arising from the orthodontic appliance. We recommend a thorough assessment to rule out any underlying oral pathology or mechanical issues related to the metal brackets attached to the maxillary incisors.
# real: The patient needs to be referred for further evaluation of possible complications arising from the orthodontic appliance. We recommend a thorough assessment to rule out any underlying oral pathology or mechanical issues related to the metal brackets attached to the maxillary incisors.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The findings suggest the presence of a potentially obstructive lesion at the level of the foramen of Monro, necessitating further neurological evaluation and possible intervention. Your expertise in neurosurgery would be invaluable in determining the next steps for the patient's management.
# real: Referral Reason: The findings suggest the presence of a potentially obstructive lesion at the level of the foramen of Monro, necessitating further neurological evaluation and possible intervention. Your expertise in neurosurgery would be invaluable in determining the next steps for the patient's management.
# 93.40906234779496
#
# ----------------------------------------------------------------
# predict: Ms. Doe exhibits three new formations of neurofibromatic masses on the left side of her palate and sublingual area as noted during her recent oral examination. These findings necessitate further specialized evaluation and management.
# real: Ms. Doe exhibits three new formations of neurofibromatic masses on the left side of her palate and sublingual area as noted during her recent oral examination. These findings necessitate further specialized evaluation and management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for this referral is the diagnosis of neck metastasis with an unknown primary tumor. During a diagnostic flexible laryngoscopy, a small ulcerative lesion was observed on the laryngeal side of the epiglottis. Although an examination under general anesthesia did not reveal a malignancy, further specialized assessment and management are required to determine the primary tumor's origin and appropriate treatment protocol.
# real: The primary reason for this referral is the diagnosis of neck metastasis with an unknown primary tumor. During a diagnostic flexible laryngoscopy, a small ulcerative lesion was observed on the laryngeal side of the epiglottis. Although an examination under general anesthesia did not reveal a malignancy, further specialized assessment and management are required to determine the primary tumor's origin and appropriate treatment protocol.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the specificity and urgency of his condition, it is imperative that Mr. Doe receives further specialized retinal evaluation and appropriate management.
# real: Given the specificity and urgency of his condition, it is imperative that Mr. Doe receives further specialized retinal evaluation and appropriate management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is that Mr. Davis has developed persistent leukocytosis over the past 6 years while on his current medication. His medical history remains otherwise unremarkable.
# real: The reason for this referral is that Mr. Davis has developed persistent leukocytosis over the past 6 years while on his current medication. His medical history remains otherwise unremarkable.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: I believe further expertise is required to evaluate and manage the complications observed in cases of post-transplantation pulmonary alveolar proteinosis.
# real: I believe further expertise is required to evaluate and manage the complications observed in cases of post-transplantation pulmonary alveolar proteinosis.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Doe requires further orthopedic evaluation and management of his fractures and the damaged SSSC ring affecting three different regions.
# real: Mr. Doe requires further orthopedic evaluation and management of his fractures and the damaged SSSC ring affecting three different regions. I would appreciate your expert attention and recommendations for his ongoing care.
# 55.38235798307589
#
# ----------------------------------------------------------------
# predict: The histological findings will determine if there’s a need for further oncologic evaluation or treatment.
# real: The histological findings will determine if there’s a need for further oncologic evaluation or treatment.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Doe should be evaluated for possible surgical intervention to excise the calcified nodules, as they are numerous and cause significant discomfort.
# real: Mr. Doe should be evaluated for possible surgical intervention to excise the calcified nodules, as they are numerous and cause significant discomfort. He does not have any systemic metabolic disorders, but the inflammation and rupture of the epidermoid cysts necessitate specialized care.
# 41.47829116815816
#
# ----------------------------------------------------------------
# predict: Referral Reason: Currently, Mr. Doe is stable with no fever, abdominal pain, or jaundice. He requires further management and evaluation of potential surgical options for the removal of gallstones to prevent future episodes of pancreatitis.
# real: Referral Reason: Currently, Mr. Doe is stable with no fever, abdominal pain, or jaundice. He requires further management and evaluation of potential surgical options for the removal of gallstones to prevent future episodes of pancreatitis.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is recommended for further diagnostic evaluation and management of a suspected mandibular lesion. Given the size and duration of the swelling, as well as its radiographic appearance, a specialist's input is essential for accurate diagnosis and appropriate treatment planning.
# real: The referral is recommended for further diagnostic evaluation and management of a suspected mandibular lesion. Given the size and duration of the swelling, as well as its radiographic appearance, a specialist's input is essential for accurate diagnosis and appropriate treatment planning.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for this referral is the presence of a holosystolic murmur identified during her physical examination. The murmur is located between the S1 and S2 heart sounds and has frequency components extending to 600 Hz, as indicated by the spectrographic analysis. Given these findings, there is a high likelihood of serious cardiac implications that require a pediatric cardiologist's expertise for further diagnosis and treatment.
# real: The primary reason for this referral is the presence of a holosystolic murmur identified during her physical examination. The murmur is located between the S1 and S2 heart sounds and has frequency components extending to 600 Hz, as indicated by the spectrographic analysis. Given these findings, there is a high likelihood of serious cardiac implications that require a pediatric cardiologist's expertise for further diagnosis and treatment.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for this referral is the patient's complex vascular anatomy complicated by her age and cancer diagnosis. Treatment or management by a specialist in vascular surgery is advised.
# real: The primary reason for this referral is the patient's complex vascular anatomy complicated by her age and cancer diagnosis. Treatment or management by a specialist in vascular surgery is advised.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient requires a specialist consultation for further evaluation and possible alternative treatment options to effectively manage his persistent lesion. Given his unresponsive disease course to intralesional SSG therapy, advanced therapeutic strategies may be necessary.
# real: The patient requires a specialist consultation for further evaluation and possible alternative treatment options to effectively manage his persistent lesion. Given his unresponsive disease course to intralesional SSG therapy, advanced therapeutic strategies may be necessary.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for referral is the recent development of a red telangiectatic macula at the prior hemangioma site. Given the current response and the planned tapering off of Propranolol after she reaches 18 months of age, a specialist's opinion is required to ensure optimal long-term management.
# real: The reason for referral is the recent development of a red telangiectatic macula at the prior hemangioma site. Given the current response and the planned tapering off of Propranolol after she reaches 18 months of age, a specialist's opinion is required to ensure optimal long-term management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mrs. Doe requires further oncological assessment and potential adjuvant therapy given the clinical presentation and surgical findings. Despite the absence of tumor invasion into the fat, further evaluation is necessary to determine the appropriate course of post-surgical treatment.
# real: Referral Reason: Mrs. Doe requires further oncological assessment and potential adjuvant therapy given the clinical presentation and surgical findings. Despite the absence of tumor invasion into the fat, further evaluation is necessary to determine the appropriate course of post-surgical treatment.
# 93.10627797040233
#
# ----------------------------------------------------------------
# predict: Mr. Doe has been experiencing repeated right lower abdominal pain for the past 5 years. His medical history includes multiple visits to our hospital, during which standard treatments have provided only temporary relief. Given the chronic nature and persistence of his symptoms, we believe that specialized intervention is warranted.
# real: Mr. Doe has been experiencing repeated right lower abdominal pain for the past 5 years. His medical history includes multiple visits to our hospital, during which standard treatments have provided only temporary relief. Given the chronic nature and persistence of his symptoms, we believe that specialized intervention is warranted.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Following the procedure, which involved the use of plain mepivacaine and Gow-Gates injection, the patient experienced immediate blanching in the infraorbital, buccal, and palatal regions. Given this unusual reaction, a specialist's evaluation is recommended to rule out any underlying issues or complications.
# real: Following the procedure, which involved the use of plain mepivacaine and Gow-Gates injection, the patient experienced immediate blanching in the infraorbital, buccal, and palatal regions. Given this unusual reaction, a specialist's evaluation is recommended to rule out any underlying issues or complications.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: I believe Mr. Doe requires an urgent consultation for further evaluation and surgical consideration due to the rapid progression of symptoms and significant neurological impairment.
# real: I believe Mr. Doe requires an urgent consultation for further evaluation and surgical consideration due to the rapid progression of symptoms and significant neurological impairment.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given these findings, we recommend a specialist evaluation to determine the nature and appropriate management of the cystic mass identified in the appendix region.
# ...
# predict: The reason for this referral is to seek further evaluation and management of the patient's ectopic thyroid tissue and associated conditions, ensuring optimal intervention strategies.
# real: The reason for this referral is to seek further evaluation and management of the patient's ectopic thyroid tissue and associated conditions, ensuring optimal intervention strategies.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is the suspected serious interaction between melatonin and citalopram. Our tests have shown that melatonin products, including the one used by the patient, exhibit cytochrome P450 (CYP) 2C19 inhibitory activity in vitro. Given that citalopram is metabolized by CYP2C19, we suspect a combined pharmacodynamic and pharmacokinetic interaction, which has not been previously documented.
# real: The reason for this referral is the suspected serious interaction between melatonin and citalopram. Our tests have shown that melatonin products, including the one used by the patient, exhibit cytochrome P450 (CYP) 2C19 inhibitory activity in vitro. Given that citalopram is metabolized by CYP2C19, we suspect a combined pharmacodynamic and pharmacokinetic interaction, which has not been previously documented.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient presents with features suggestive of drusen, which mimic the appearance of true papilledema. Given the need for a thorough evaluation to rule out any misleading symptoms associated with such conditions, your expertise is highly sought.
# real: The patient presents with features suggestive of drusen, which mimic the appearance of true papilledema. Given the need for a thorough evaluation to rule out any misleading symptoms associated with such conditions, your expertise is highly sought.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is her persistent symptoms despite initial treatment, which suggest a potential underlying condition that requires further specialist assessment and management.
# real: The reason for this referral is her persistent symptoms despite initial treatment, which suggest a potential underlying condition that requires further specialist assessment and management.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Jane Doe was recently diagnosed with endometrial cancer at the age of 42. Given the significant family history of colorectal, endometrial, ovarian, and kidney cancers, I have conducted mismatch repair (MMR) analysis by immunohistochemistry on her tumor tissue. Due to these findings, I recommend a comprehensive review and potential genetic counseling to assess hereditary cancer risk.
# real: Jane Doe was recently diagnosed with endometrial cancer at the age of 42. Given the significant family history of colorectal, endometrial, ovarian, and kidney cancers, I have conducted mismatch repair (MMR) analysis by immunohistochemistry on her tumor tissue. Due to these findings, I recommend a comprehensive review and potential genetic counseling to assess hereditary cancer risk.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Ms. Doe presented with a serous pigment epithelium detachment (PED) accompanied by subretinal hemorrhage and lipid exudation. Given the complexity and progression of her condition, I believe she would benefit from specialized ophthalmologic assessment and management.
# real: Given the complexity and progression of her condition, I believe she would benefit from specialized ophthalmologic assessment and management.
# 48.087191456532125
#
# ----------------------------------------------------------------
# predict: The reason for referral is for a specialized ENT follow-up to ensure the proper healing of the endolaryngeal injury and to rule out any potential complications that may arise during the recovery period.
# real: The reason for referral is for a specialized ENT follow-up to ensure the proper healing of the endolaryngeal injury and to rule out any potential complications that may arise during the recovery period.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The primary reason for referral is the patient's persistent development of dermatological lesions following suspected contact with caterpillars. Despite initial treatment with betamethasone valerate 0.1% cream, the condition has not resolved entirely, and further specialist evaluation is warranted to rule out any potential secondary complications and to optimize treatment strategies.
# real: The primary reason for referral is the patient's persistent development of dermatological lesions following suspected contact with caterpillars. Despite initial treatment with betamethasone valerate 0.1% cream, the condition has not resolved entirely, and further specialist evaluation is warranted to rule out any potential secondary complications and to optimize treatment strategies.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral reason is the suspicion of an atrial mass. A recent CMR study showed extensive caseous calcification of the posterior mitral annulus, measuring 3 x 2.5 cm with a circumferential extension of about 5 cm. This mass is located in the basal inferior wall of the left ventricle, bulging into the posterior left atrium, but without significant mitral valve regurgitation.
# real: The referral reason is the suspicion of an atrial mass. A recent CMR study showed extensive caseous calcification of the posterior mitral annulus, measuring 3 x 2.5 cm with a circumferential extension of about 5 cm. This mass is located in the basal inferior wall of the left ventricle, bulging into the posterior left atrium, but without significant mitral valve regurgitation.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to seek your expert opinion and consider potential advanced therapeutic interventions that could assist in managing his PSP symptoms more effectively.
# real: The reason for this referral is to seek your expert opinion and consider potential advanced therapeutic interventions that could assist in managing his PSP symptoms more effectively.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is being made due to Mr. Doe's sustained neutropenia and newly developed eosinophilia. The patient was initially administered vancomycin, which was switched to ceftaroline due to an increase in serum creatinine. During the course of ceftaroline treatment, the patient became neutropenic and later developed eosinophilia, prompting a switch to daptomycin. His most recent WBC on day 14 was 2900 cells/mm3 with 61.4% neutrophils, indicating persistent neutropenia.
# real: The referral is being made due to Mr. Doe's sustained neutropenia and newly developed eosinophilia. The patient was initially administered vancomycin, which was switched to ceftaroline due to an increase in serum creatinine. During the course of ceftaroline treatment, the patient became neutropenic and later developed eosinophilia, prompting a switch to daptomycin. His most recent WBC on day 14 was 2900 cells/mm3 with 61.4% neutrophils, indicating persistent neutropenia.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is the need for further investigation and specialized treatment of the friable mass, which was identified on colonoscopy. Biopsies of the mass revealed hyaline rings surrounding histiocytes or multinucleated giant cells along with vegetable debris, suggesting an unusual pathology that warrants further exploration by a specialist.
# real: The reason for this referral is the need for further investigation and specialized treatment of the friable mass, which was identified on colonoscopy. Biopsies of the mass revealed hyaline rings surrounding histiocytes or multinucleated giant cells along with vegetable debris, suggesting an unusual pathology that warrants further exploration by a specialist.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The imaging studies confirm the diagnosis of canal of Nuck hydrocele. The patient requires further evaluation and potential management by a pediatric surgeon to determine the appropriate treatment plan.
# real: The imaging studies confirm the diagnosis of canal of Nuck hydrocele. The patient requires further evaluation and potential management by a pediatric surgeon to determine the appropriate treatment plan.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Due to the incidental finding of the renal mass and subsequent confirmation of renal cell carcinoma, Mr. Doe requires specialized oncological assessment and potential follow-up treatments. Given his professional background and personal medical history, further evaluation and management by a renal cancer specialist are warranted to ensure optimal outcomes.
# real: Due to the incidental finding of the renal mass and subsequent confirmation of renal cell carcinoma, Mr. Doe requires specialized oncological assessment and potential follow-up treatments. Given his professional background and personal medical history, further evaluation and management by a renal cancer specialist are warranted to ensure optimal outcomes.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Due to the coexistence of DT and BCC in the histological findings and considering the patient's age and overall health, I recommend further dermatological surveillance to ensure there are no new or recurrent malignancies.
# real: Due to the coexistence of DT and BCC in the histological findings and considering the patient's age and overall health, I recommend further dermatological surveillance to ensure there are no new or recurrent malignancies.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The reason for this referral is to further evaluate and manage her recurrent respiratory infections and bronchiectasis. Given the frequency and severity of her symptoms, a comprehensive evaluation including imaging studies such as a CT scan is recommended to better understand her condition and guide future treatment strategies.
# real: The reason for this referral is to further evaluate and manage her recurrent respiratory infections and bronchiectasis. Given the frequency and severity of her symptoms, a comprehensive evaluation including imaging studies such as a CT scan is recommended to better understand her condition and guide future treatment strategies.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Mr. Smith's chronic eczema has not been responsive to over-the-counter topical treatments and requires specialized dermatological care. Given his complex medical history and the persistence of his symptoms, a comprehensive assessment and tailored treatment plan from your expertise are necessary.
# real: Mr. Smith's chronic eczema has not been responsive to over-the-counter topical treatments and requires specialized dermatological care. Given his complex medical history and the persistence of his symptoms, a comprehensive assessment and tailored treatment plan from your expertise are necessary.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is to ensure long-term management and to evaluate the potential need for future interventions to prevent recurrence. Your expertise would be greatly appreciated in providing a comprehensive treatment plan.
# real: The referral is to ensure long-term management and to evaluate the potential need for future interventions to prevent recurrence. Your expertise would be greatly appreciated in providing a comprehensive treatment plan.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The referral is made due to the complexity of the tissue and bone damage which requires further specialized care, particularly for assessment of potential long-term functional impairment and additional reconstructive options.
# real: The referral is made due to the complexity of the tissue and bone damage which requires further specialized care, particularly for assessment of potential long-term functional impairment and additional reconstructive options.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: The patient needs referral due to the presence of abnormal gender characteristics including microorchidism and mild bilateral gynecomastia. Additional specialized evaluation and management are crucial to address these endocrine issues.
# real: The patient needs referral due to the presence of abnormal gender characteristics including microorchidism and mild bilateral gynecomastia. Additional specialized evaluation and management are crucial to address these endocrine issues.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict: Given the neonatologist's suspicion of a congenital anal fissure, I would like to request your expert consultation to confirm the diagnosis and discuss potential management options.
# real: Given the neonatologist's suspicion of a congenital anal fissure, I would like to request your expert consultation to confirm the diagnosis and discuss potential management options.
# 100.00000000000004
#
# ----------------------------------------------------------------
# predict:
# real: I am referring Mrs. Jane Doe, a 68-year-old woman, for further evaluation and management of her allergic reaction suspected to be due to hyaluronidase.
# 0.0
#
# ----------------------------------------------------------------
# predict: Referral Reason: Despite the surgical intervention and current symptomatic improvement, recurrent episodes of oesophageal stricture and the underlying microcytic anaemia warrant further specialist evaluation. Comprehensive gastroenterological assessment and long-term management strategies are necessary to ensure the stability and overall well-being of the patient.
# real: Despite the surgical intervention and current symptomatic improvement, recurrent episodes of oesophageal stricture and the underlying microcytic anaemia warrant further specialist evaluation. Comprehensive gastroenterological assessment and long-term management strategies are necessary to ensure the stability and overall well-being of the patient.
# 93.40246756077242
#
# ----------------------------------------------------------------
# predict: The referral is requested due to the patient's elevated serum ammonia levels (148 mcg/dl) following the increase of VPA to 1500 mg. Despite normal VPA levels (56.2 mg/L), he developed constipation and altered sensorium. Prompt discontinuation of VPA and initiation of lactulose resulted in his condition improving within 2 days. A gastroenterology consult was performed, but further specialist input is required to manage his elevated ammonia levels and ensure comprehensive care.
# real: The referral is requested due to the patient's elevated serum ammonia levels (148 mcg/dl) following the increase of VPA to 1500 mg. Despite normal VPA levels (56.2 mg/L), he developed constipation and altered sensorium. Prompt discontinuation of VPA and initiation of lactulose resulted in his condition improving within 2 days. A gastroenterology consult was performed, but further specialist input is required to manage his elevated ammonia levels and ensure comprehensive care.
# 100.00000000000004
#
# CSV file has been saved to llama3_funetune_test.csv

# %%
def analyze_predict_data(bleu_score_list):
    # 统计大于100的个数
    count_gt_100 = sum(1 for score in bleu_score_list if score >= 100)

    # 统计大于70的个数
    count_gt_70 = sum(1 for score in bleu_score_list if score > 70)

    prob_gt_100 = count_gt_100 / len(bleu_score_list)
    prob_gt_70 = count_gt_70 / len(bleu_score_list)
    average_score = sum(bleu_score_list) / float(len(bleu_score_list))

    print(f"分数大于100的个数：{count_gt_100}, 占所有数据的百分比为： {prob_gt_100}")
    print(f"分数大于70的个数：{count_gt_70}, 占所有数据的百分比为： {prob_gt_70}")
    print(f"bleu平均分数: {average_score}")

# %%
analyze_predict_data(test_bleu_score_list)
# Out:
# 分数大于100的个数：119, 占所有数据的百分比为： 0.85
# 分数大于70的个数：123, 占所有数据的百分比为： 0.8785714285714286
# bleu平均分数: 89.56097533162449
